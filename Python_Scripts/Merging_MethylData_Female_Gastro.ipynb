# %%
import pandas as pd
import numpy as np
# %cd Z:\PPMI_Data\Excels\Raw_And_More
# Out:
# Z:\PPMI_Data\Excels\Raw_And_More

# %%
Cpg_File = pd.read_csv ("beta_post_Funnorm_PPMI_EPICn524final030618.csv")
Cpg_File.head(3)
# Out:
#             200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# cg14817997             0.834027             0.849201             0.772995
# cg26928153             0.945589             0.948538             0.962199
# cg16269199             0.845186             0.911488             0.948206
#
#             200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# cg14817997             0.885288             0.772547             0.756429
# cg26928153             0.944048             0.926306             0.956061
# cg16269199             0.913622             0.778551             0.903924
#
#             200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  \
# cg14817997             0.719766             0.775910             0.768914
# cg26928153             0.912988             0.955983             0.957120
# cg16269199             0.742258             0.934683             0.897787
#
#             200973410167_R05C01  ...  200989060089_R02C01  \
# ...

# %%
Cpg_File.index.name ='CpG'
Cpg_File.reset_index(inplace=True)
Cpg_File.head(3)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg14817997             0.834027             0.849201             0.772995
# 1  cg26928153             0.945589             0.948538             0.962199
# 2  cg16269199             0.845186             0.911488             0.948206
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0             0.885288             0.772547             0.756429
# 1             0.944048             0.926306             0.956061
# 2             0.913622             0.778551             0.903924
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0             0.719766             0.775910             0.768914  ...
# 1             0.912988             0.955983             0.957120  ...
# 2             0.742258             0.934683             0.897787  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# ...

# %%
# %cd Z:\PPMI_Data\Excels\Only_Female\GeneCpG\Gastro
df1 = pd.read_csv ("CpG_Gastro_Gene.csv")
df1.head(2)
# Out:
# Z:\PPMI_Data\Excels\Only_Female\GeneCpG\Gastro
#    Gene         CpG
# 0  ABAT  cg03441945
# 1  ABAT  cg21094410

# %%
df = pd.merge (df1, Cpg_File, on = 'CpG', how = 'inner')
df.head(2)
# Out:
#    Gene         CpG  200973410159_R03C01  200991620021_R01C01  \
# 0  ABAT  cg03441945             0.892410             0.908813
# 1  ABAT  cg21094410             0.015756             0.011350
#
#    200991620021_R03C01  200989060105_R03C01  200989060135_R07C01  \
# 0             0.922532             0.876056             0.813126
# 1             0.013309             0.011801             0.012203
#
#    200989060162_R04C01  200973410167_R04C01  200973410143_R01C01  ...  \
# 0             0.935165             0.866976             0.905115  ...
# 1             0.008164             0.022294             0.010226  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# 0             0.896406             0.882445             0.888929
# 1             0.011297             0.009869             0.010037
#
#    200973410143_R08C01  200973410143_R07C01  200989060089_R03C01  \
# 0             0.899099             0.884275             0.875572
# ...

# %%
df = df.drop('Gene', axis=1)

# %%
dft = df.transpose()
dft.head(2)
# Out:
#                           0           1           2           3      \
# CpG                  cg03441945  cg21094410  cg22926093  cg25025609
# 200973410159_R03C01     0.89241    0.015756    0.011101    0.018491
#
#                           4           5           6           7      \
# CpG                  cg16704802  cg06228737  cg00220102  cg19016494
# 200973410159_R03C01    0.020476    0.962482    0.677222     0.02956
#
#                           8           9      ...       33994       33995  \
# CpG                  cg12247200  cg24658413  ...  cg12522722  cg11255513
# 200973410159_R03C01    0.929821    0.899519  ...    0.909955    0.043985
#
#                           33996       33997       33998       33999  \
# CpG                  cg09615521  cg12658517  cg02150941  cg22992837
# 200973410159_R03C01    0.054816    0.904326    0.135138    0.742557
#
#                           34000       34001       34002       34003
# ...

# %%
dft.rename(columns=dft.iloc[0], inplace = True)
dft.head(2)
# Out:
#                      cg03441945  cg21094410  cg22926093  cg25025609  \
# CpG                  cg03441945  cg21094410  cg22926093  cg25025609
# 200973410159_R03C01     0.89241    0.015756    0.011101    0.018491
#
#                      cg16704802  cg06228737  cg00220102  cg19016494  \
# CpG                  cg16704802  cg06228737  cg00220102  cg19016494
# 200973410159_R03C01    0.020476    0.962482    0.677222     0.02956
#
#                      cg12247200  cg24658413  ...  cg12522722  cg11255513  \
# CpG                  cg12247200  cg24658413  ...  cg12522722  cg11255513
# 200973410159_R03C01    0.929821    0.899519  ...    0.909955    0.043985
#
#                      cg09615521  cg12658517  cg02150941  cg22992837  \
# CpG                  cg09615521  cg12658517  cg02150941  cg22992837
# 200973410159_R03C01    0.054816    0.904326    0.135138    0.742557
#
#                      cg02699881  cg05225390  cg01481208  cg08634588
# ...

# %%
dft.index.name ='CpG'
dft.reset_index(inplace=True)
dft.head(2)
# Out:
#                    CpG  cg03441945  cg21094410  cg22926093  cg25025609  \
# 0                  CpG  cg03441945  cg21094410  cg22926093  cg25025609
# 1  200973410159_R03C01     0.89241    0.015756    0.011101    0.018491
#
#    cg16704802  cg06228737  cg00220102  cg19016494  cg12247200  ...  \
# 0  cg16704802  cg06228737  cg00220102  cg19016494  cg12247200  ...
# 1    0.020476    0.962482    0.677222     0.02956    0.929821  ...
#
#    cg12522722  cg11255513  cg09615521  cg12658517  cg02150941  cg22992837  \
# 0  cg12522722  cg11255513  cg09615521  cg12658517  cg02150941  cg22992837
# 1    0.909955    0.043985    0.054816    0.904326    0.135138    0.742557
#
#    cg02699881  cg05225390  cg01481208  cg08634588
# 0  cg02699881  cg05225390  cg01481208  cg08634588
# 1    0.029678    0.079017    0.894593    0.902949
#
# [2 rows x 34005 columns]

# %%
dft = dft.drop ([0], axis = 0)
dft.head(2)
# Out:
#                    CpG cg03441945 cg21094410 cg22926093 cg25025609 cg16704802  \
# 1  200973410159_R03C01    0.89241   0.015756   0.011101   0.018491   0.020476
# 2  200991620021_R01C01   0.908813    0.01135   0.012197   0.022372   0.018128
#
#   cg06228737 cg00220102 cg19016494 cg12247200  ... cg12522722 cg11255513  \
# 1   0.962482   0.677222    0.02956   0.929821  ...   0.909955   0.043985
# 2   0.945195   0.730494   0.017911   0.921435  ...   0.900398   0.043525
#
#   cg09615521 cg12658517 cg02150941 cg22992837 cg02699881 cg05225390  \
# 1   0.054816   0.904326   0.135138   0.742557   0.029678   0.079017
# 2   0.043829   0.899376   0.078902   0.754703   0.030224   0.075161
#
#   cg01481208 cg08634588
# 1   0.894593   0.902949
# 2   0.909315   0.903716
#
# [2 rows x 34005 columns]

# %%
dft.rename (columns = {"CpG" : "Sentrix"}, inplace = True)
dft.head(2)
# Out:
#                Sentrix cg03441945 cg21094410 cg22926093 cg25025609 cg16704802  \
# 1  200973410159_R03C01    0.89241   0.015756   0.011101   0.018491   0.020476
# 2  200991620021_R01C01   0.908813    0.01135   0.012197   0.022372   0.018128
#
#   cg06228737 cg00220102 cg19016494 cg12247200  ... cg12522722 cg11255513  \
# 1   0.962482   0.677222    0.02956   0.929821  ...   0.909955   0.043985
# 2   0.945195   0.730494   0.017911   0.921435  ...   0.900398   0.043525
#
#   cg09615521 cg12658517 cg02150941 cg22992837 cg02699881 cg05225390  \
# 1   0.054816   0.904326   0.135138   0.742557   0.029678   0.079017
# 2   0.043829   0.899376   0.078902   0.754703   0.030224   0.075161
#
#   cg01481208 cg08634588
# 1   0.894593   0.902949
# 2   0.909315   0.903716
#
# [2 rows x 34005 columns]

# %%
df2 = pd.read_csv ("Gastro_with_PATNO_APPRDX_Age_in524Methyl_Female.csv")
df3 = pd.merge (df2, dft, on= "Sentrix", how= "inner")
print(df3.shape)
df3.head(2)
# Out:
# (150, 34012)
#                Sentrix  PATNO  Gender  APPRDX  HYS   Age  AgeCate  \
# 0  200973410159_R03C01   3000       2       2    0  69.1        4
# 1  200991620021_R03C01   3002       2       1    2  67.6        4
#
#    SCOPA_Gastro_Category cg03441945 cg21094410  ... cg12522722 cg11255513  \
# 0                      0    0.89241   0.015756  ...   0.909955   0.043985
# 1                      1   0.922532   0.013309  ...    0.93175   0.051855
#
#   cg09615521 cg12658517 cg02150941 cg22992837 cg02699881 cg05225390  \
# 0   0.054816   0.904326   0.135138   0.742557   0.029678   0.079017
# 1   0.039594    0.92165   0.074618   0.843395   0.020945   0.058536
#
#   cg01481208 cg08634588
# 0   0.894593   0.902949
# 1   0.872011   0.890447
#
# [2 rows x 34012 columns]

# %%
df3.to_csv ("Gastro_with_MethylomeDetails_Female.csv", index=False)
