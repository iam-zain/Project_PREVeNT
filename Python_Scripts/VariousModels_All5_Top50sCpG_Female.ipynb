# %%
import joblib
import numpy as np
import pandas as pd
from sklearn.svm import SVC
from xgboost import XGBClassifier
from scipy.stats import kurtosis, skew
from sklearn.model_selection import KFold
from sklearn.metrics import accuracy_score
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import StratifiedKFold
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV

# %%
# %cd Z:\PPMI_Data\Excels\NonMotors\The251\Female\Model_CpG
NonMot = pd.read_csv('All5_Top50sCpG_Female.csv')
CpG_Data = NonMot.drop(['PATNO'], axis = 1)
CpG_Data['APPRDX'] = CpG_Data['APPRDX'].replace([1], 'Patient')
CpG_Data['APPRDX'] = CpG_Data['APPRDX'].replace([2], 'Healthy')
CpG_Data.head(2)
# Out:
# Z:\PPMI_Data\Excels\NonMotors\The251\Female\Model_CpG
#     APPRDX  cg11668199  cg04983473  cg25943702  cg01620849  cg22210403  \
# 0  Patient    0.045694    0.924158    0.908038    0.033501     0.07147
# 1  Patient    0.050506    0.929821    0.928079    0.032749     0.06974
#
#    cg21241862  cg19030090  cg02232418  cg18757169  ...  cg14548871  \
# 0    0.904030    0.917645    0.830685    0.506640  ...    0.027095
# 1    0.914086    0.889673    0.768925    0.535331  ...    0.018183
#
#    cg04721557  cg17218282  cg20471798  cg04948892  cg12751142  cg17957325  \
# 0    0.939462    0.767832    0.845091    0.156538    0.510861    0.922070
# 1    0.939685    0.778352    0.820209    0.150134    0.622603    0.929889
#
#    cg13520090  cg05538980  cg18580385
# 0    0.877443    0.792984    0.895246
# 1    0.778461    0.763160    0.887588
#
# [2 rows x 229 columns]

# %% [markdown]
# # Naive Based

# %%
output = []
for i in range(1, 101):
    print(i)
    kfold = KFold(n_splits=10, shuffle=True, random_state=i)
    accuracies = []
    for train_index, test_index in kfold.split(CpG_Data.drop('APPRDX', axis=1), CpG_Data['APPRDX']):
        train_data, test_data = CpG_Data.iloc[train_index].drop('APPRDX', axis=1), CpG_Data.iloc[test_index].drop('APPRDX', axis=1)
        train_labels, test_labels = CpG_Data.iloc[train_index]['APPRDX'], CpG_Data.iloc[test_index]['APPRDX']
    
        nb_model = GaussianNB()
        nb_model.fit(train_data, train_labels)
    
        predictions = nb_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        accuracies.append(accuracy)
    mean_accuracy = np.mean(accuracies)
    print(f'Mean accuracy: {mean_accuracy}')
    output.append(mean_accuracy)

np.savetxt("All5_Top50sCpG_Female_100NaiveBayes_10fold.csv", output, delimiter=",")
# Out:
# 1
# Mean accuracy: 0.7733333333333333
# 2
# Mean accuracy: 0.7266666666666668
# 3
# Mean accuracy: 0.7333333333333334
# 4
# Mean accuracy: 0.7733333333333333
# 5
# Mean accuracy: 0.7666666666666666
# 6
# Mean accuracy: 0.7466666666666667
# 7
# Mean accuracy: 0.76
# 8
# Mean accuracy: 0.7466666666666667
# 9
# Mean accuracy: 0.7533333333333334
# 10
# Mean accuracy: 0.7533333333333333
# 11
# Mean accuracy: 0.7733333333333333
# 12
# Mean accuracy: 0.7266666666666667
# 13
# Mean accuracy: 0.7666666666666667
# 14
# Mean accuracy: 0.7533333333333333
# 15
# Mean accuracy: 0.7666666666666666
# 16
# Mean accuracy: 0.7733333333333333
# 17
# Mean accuracy: 0.7733333333333333
# 18
# Mean accuracy: 0.7466666666666666
# 19
# Mean accuracy: 0.7666666666666666
# 20
# Mean accuracy: 0.76
# 21
# Mean accuracy: 0.7533333333333334
# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                                                CpG_Data['APPRDX'], test_size=0.2)
        
        nb_model = GaussianNB()
        nb_model.fit(train_data, train_labels)
        
        predictions = nb_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_NaiveBased.csv", output, delimiter=",")
        joblib.dump(nb_model, f"{col}_NaiveBased_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.8333333333333334
# Accuracy for column cg04983473: 0.7333333333333333
# Accuracy for column cg25943702: 0.6666666666666666
# Accuracy for column cg01620849: 0.7666666666666667
# Accuracy for column cg22210403: 0.8
# Accuracy for column cg21241862: 0.6666666666666666
# Accuracy for column cg19030090: 0.8
# Accuracy for column cg02232418: 0.7333333333333333
# Accuracy for column cg18757169: 0.7
# Accuracy for column cg02992048: 0.5333333333333333
# Accuracy for column cg22810281: 0.7666666666666667
# Accuracy for column cg17780657: 0.6333333333333333
# Accuracy for column cg20230179: 0.6666666666666666
# Accuracy for column cg24573261: 0.7
# Accuracy for column cg08497332: 0.6333333333333333
# Accuracy for column cg15442746: 0.7333333333333333
# Accuracy for column cg23641264: 0.7666666666666667
# Accuracy for column cg13002109: 0.8
# Accuracy for column cg10848291: 0.7
# Accuracy for column cg07010694: 0.6666666666666666
# Accuracy for column cg18281829: 0.7666666666666667
# Accuracy for column cg06977831: 0.8333333333333334
# Accuracy for column cg24576735: 0.8
# Accuracy for column cg06017944: 0.6666666666666666
# Accuracy for column cg12077460: 0.7666666666666667
# Accuracy for column cg03929615: 0.7666666666666667
# Accuracy for column cg01686420: 0.8
# Accuracy for column cg16308148: 0.6333333333333333
# Accuracy for column cg09733916: 0.7333333333333333
# Accuracy for column cg25844977: 0.8
# Accuracy for column cg08369141: 0.6666666666666666
# Accuracy for column cg25823996: 0.8
# Accuracy for column cg05015348: 0.7
# Accuracy for column cg18497960: 0.5333333333333333
# Accuracy for column cg18830699: 0.8333333333333334
# Accuracy for column cg18319799: 0.7333333333333333
# Accuracy for column cg04954056: 0.7333333333333333
# Accuracy for column cg09902448: 0.8
# Accuracy for column cg00319242: 0.6666666666666666
# Accuracy for column cg05125128: 0.7666666666666667
# Accuracy for column cg26819590: 0.7
# Accuracy for column cg14587401: 0.8
# Accuracy for column cg06191029: 0.7
# Accuracy for column cg14270890: 0.7666666666666667
# Accuracy for column cg22237213: 0.6
# Accuracy for column cg06630567: 0.7333333333333333
# Accuracy for column cg26856497: 0.7666666666666667
# Accuracy for column cg23565749: 0.6333333333333333
# Accuracy for column cg12413242: 0.8333333333333334
# Accuracy for column cg24784310: 0.7
# Accuracy for column cg04359365: 0.8
# Accuracy for column cg00265238: 0.5666666666666667
# Accuracy for column cg21877355: 0.7666666666666667
# Accuracy for column ch.3.3596501R: 0.8333333333333334
# Accuracy for column cg05769889: 0.7333333333333333
# Accuracy for column cg14385965: 0.7666666666666667
# Accuracy for column cg19441674: 0.6666666666666666
# Accuracy for column cg20170632: 0.7333333333333333
# Accuracy for column cg25114899: 0.8333333333333334
# Accuracy for column cg27129641: 0.7333333333333333
# Accuracy for column cg26704870: 0.6666666666666666
# Accuracy for column cg04221681: 0.5333333333333333
# Accuracy for column cg23690866: 0.7333333333333333
# Accuracy for column cg03817303: 0.7666666666666667
# Accuracy for column cg14612428: 0.7666666666666667
# Accuracy for column cg09837559: 0.6
# Accuracy for column cg06620193: 0.5
# Accuracy for column cg09368832: 0.6
# Accuracy for column cg17196875: 0.7333333333333333
# Accuracy for column cg11943389: 0.7
# Accuracy for column cg09602742: 0.7
# Accuracy for column cg25578728: 0.5333333333333333
# Accuracy for column cg00346755: 0.6666666666666666
# Accuracy for column cg21379625: 0.7333333333333333
# Accuracy for column cg06310816: 0.7
# Accuracy for column cg09901201: 0.6666666666666666
# Accuracy for column cg19320612: 0.6
# Accuracy for column cg01869632: 0.6333333333333333
# Accuracy for column cg03573792: 0.8
# Accuracy for column cg14548871: 0.7333333333333333
# Accuracy for column cg04721557: 0.7666666666666667
# Accuracy for column cg17218282: 0.8333333333333334
# Accuracy for column cg20471798: 0.7666666666666667
# Accuracy for column cg04948892: 0.5666666666666667
# Accuracy for column cg12751142: 0.6666666666666666
# Accuracy for column cg17957325: 0.8333333333333334
# Accuracy for column cg13520090: 0.7666666666666667
# Accuracy for column cg05538980: 0.7
# Accuracy for column cg18580385: 0.6666666666666666

# %% [markdown]
# # Bagging

# %%
output = []
for i in range(1, 101):
    print(f'Run {i}')
    data = CpG_Data.drop('APPRDX', axis=1)
    labels = CpG_Data['APPRDX']
    kf = KFold(n_splits=10, shuffle=True)
    accuracies = []
    for train_index, test_index in kf.split(data):
        train_data, test_data = data.iloc[train_index], data.iloc[test_index]
        train_labels, test_labels = labels.iloc[train_index], labels.iloc[test_index]
        base_model = DecisionTreeClassifier()
        bagging_model = BaggingClassifier(base_estimator=base_model, n_estimators=10, max_samples=0.8, max_features=0.8)
        bagging_model.fit(train_data, train_labels)
        predictions = bagging_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        accuracies.append(accuracy)
    mean_accuracy = np.mean(accuracies)
    print(f'Mean accuracy: {mean_accuracy}')
    output.append(mean_accuracy)

np.savetxt("All5_Top50sCpG_Female_100bagging.csv", output, delimiter=",")
# Out:
# Run 1
# Mean accuracy: 0.7666666666666667
# Run 2
# Mean accuracy: 0.7333333333333333
# Run 3
# Mean accuracy: 0.7466666666666667
# Run 4
# Mean accuracy: 0.7466666666666667
# Run 5
# Mean accuracy: 0.7733333333333333
# Run 6
# Mean accuracy: 0.7533333333333333
# Run 7
# Mean accuracy: 0.8266666666666665
# Run 8
# Mean accuracy: 0.7666666666666667
# Run 9
# Mean accuracy: 0.7666666666666666
# Run 10
# Mean accuracy: 0.7533333333333334
# Run 11
# Mean accuracy: 0.7866666666666666
# Run 12
# Mean accuracy: 0.7533333333333333
# Run 13
# Mean accuracy: 0.8066666666666669
# Run 14
# Mean accuracy: 0.7666666666666667
# Run 81
# Mean accuracy: 0.7933333333333333
# Run 82
# Mean accuracy: 0.7866666666666665
# Run 83
# Mean accuracy: 0.7733333333333333
# Run 84
# Mean accuracy: 0.7933333333333333
# Run 85
# Mean accuracy: 0.7933333333333333
# Run 86
# Mean accuracy: 0.78
# Run 87
# Mean accuracy: 0.7866666666666666
# Run 88
# Mean accuracy: 0.7666666666666667
# Run 89
# Mean accuracy: 0.8133333333333332
# Run 90
# Mean accuracy: 0.78
# Run 91
# Mean accuracy: 0.7666666666666666
# Run 92
# Mean accuracy: 0.7266666666666668
# Run 93
# Mean accuracy: 0.7666666666666667
# Run 94
# Mean accuracy: 0.7733333333333333
# Run 95
# Mean accuracy: 0.78
# Run 96
# Mean accuracy: 0.74
# Run 97
# Mean accuracy: 0.78
# Run 98
# Mean accuracy: 0.7933333333333332
# Run 99
# Mean accuracy: 0.7866666666666667
# Run 100
# Mean accuracy: 0.78

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        X = CpG_Data[[col]]
        y = CpG_Data['APPRDX']
        
        base_model = DecisionTreeClassifier()
        bagging_model = BaggingClassifier(base_estimator=base_model, n_estimators=10, max_samples=0.8, max_features=0.8)
        bagging_model.fit(X,y)
        # 10-fold cross-validation
        scores = cross_val_score(bagging_model, X, y, cv=10)
        print(f'Accuracy for column {col}: {np.mean(scores)}')
        output.append(np.mean(scores))

        np.savetxt(f"{col}_Bag.csv", output, delimiter=",")
        joblib.dump(bagging_model, f"{col}_bag_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.6333333333333333
# Accuracy for column cg04983473: 0.6466666666666666
# Accuracy for column cg25943702: 0.5866666666666667
# Accuracy for column cg01620849: 0.6333333333333333
# Accuracy for column cg22210403: 0.6066666666666667
# Accuracy for column cg21241862: 0.6133333333333333
# Accuracy for column cg19030090: 0.64
# Accuracy for column cg02232418: 0.7
# Accuracy for column cg18757169: 0.6733333333333333
# Accuracy for column cg02992048: 0.6066666666666667
# Accuracy for column cg22810281: 0.6133333333333333
# Accuracy for column cg17780657: 0.6533333333333333
# Accuracy for column cg20230179: 0.64
# Accuracy for column cg24573261: 0.6933333333333332
# Accuracy for column cg08497332: 0.6333333333333332
# Accuracy for column cg15442746: 0.6533333333333333
# Accuracy for column cg23641264: 0.6799999999999999
# Accuracy for column cg13002109: 0.6399999999999999
# Accuracy for column cg10848291: 0.6066666666666667
# Accuracy for column cg07010694: 0.62
# Accuracy for column cg18281829: 0.62
# Accuracy for column cg06977831: 0.5733333333333334
# Accuracy for column cg24576735: 0.6799999999999999
# Accuracy for column cg06017944: 0.6533333333333333
# Accuracy for column cg12077460: 0.6799999999999999
# Accuracy for column cg03929615: 0.6799999999999999
# Accuracy for column cg01686420: 0.6466666666666667
# Accuracy for column cg16308148: 0.6266666666666667
# Accuracy for column cg09733916: 0.6133333333333333
# Accuracy for column cg25844977: 0.7266666666666668
# Accuracy for column cg08369141: 0.5933333333333335
# Accuracy for column cg25823996: 0.6866666666666665
# Accuracy for column cg05015348: 0.6933333333333334
# Accuracy for column cg18497960: 0.6199999999999999
# Accuracy for column cg03166896: 0.68
# Accuracy for column cg21409615: 0.6599999999999999
# Accuracy for column cg14074878: 0.7266666666666666
# Accuracy for column cg24752563: 0.6666666666666667
# Accuracy for column cg10644659: 0.6733333333333333
# Accuracy for column cg06512164: 0.6133333333333334
# Accuracy for column cg10387956: 0.6933333333333334
# Accuracy for column cg25696758: 0.6933333333333334
# Accuracy for column cg08592683: 0.6466666666666667
# Accuracy for column cg05226711: 0.6799999999999999
# Accuracy for column cg24282845: 0.6133333333333333
# Accuracy for column cg27262702: 0.5799999999999998
# Accuracy for column cg16919248: 0.6333333333333333
# Accuracy for column cg02488409: 0.7
# Accuracy for column cg23142730: 0.6266666666666667
# Accuracy for column cg02888917: 0.7066666666666667
# Accuracy for column cg27486833: 0.6933333333333332
# Accuracy for column cg26730369: 0.6266666666666667
# Accuracy for column cg11686092: 0.6466666666666667
# Accuracy for column cg14149699: 0.6133333333333333
# Accuracy for column cg25380030: 0.6133333333333333
# Accuracy for column cg27625479: 0.6799999999999999
# Accuracy for column cg10205430: 0.6533333333333333
# Accuracy for column cg03458463: 0.6199999999999999
# Accuracy for column cg23187886: 0.6066666666666667
# Accuracy for column cg22930773: 0.6533333333333333
# Accuracy for column cg05769889: 0.7533333333333334
# Accuracy for column cg14385965: 0.6466666666666667
# Accuracy for column cg19441674: 0.5733333333333335
# Accuracy for column cg20170632: 0.6533333333333333
# Accuracy for column cg25114899: 0.6133333333333333
# Accuracy for column cg27129641: 0.7
# Accuracy for column cg26704870: 0.6133333333333333
# Accuracy for column cg04221681: 0.6
# Accuracy for column cg23690866: 0.6666666666666666
# Accuracy for column cg03817303: 0.5933333333333333
# Accuracy for column cg14612428: 0.6199999999999999
# Accuracy for column cg09837559: 0.6
# Accuracy for column cg06620193: 0.6533333333333333
# Accuracy for column cg09368832: 0.6466666666666667
# Accuracy for column cg17196875: 0.6799999999999999
# Accuracy for column cg11943389: 0.6466666666666667
# Accuracy for column cg09602742: 0.6333333333333333
# Accuracy for column cg25578728: 0.5933333333333334
# Accuracy for column cg00346755: 0.7266666666666668
# Accuracy for column cg21379625: 0.5866666666666667
# Accuracy for column cg06310816: 0.5933333333333333
# Accuracy for column cg09901201: 0.6666666666666666
# Accuracy for column cg19320612: 0.6733333333333332
# Accuracy for column cg01869632: 0.6466666666666667
# Accuracy for column cg03573792: 0.5933333333333334
# Accuracy for column cg14548871: 0.5866666666666667
# Accuracy for column cg04721557: 0.6333333333333333
# Accuracy for column cg17218282: 0.6866666666666666
# Accuracy for column cg20471798: 0.6733333333333332
# Accuracy for column cg04948892: 0.6666666666666667
# Accuracy for column cg12751142: 0.66
# Accuracy for column cg17957325: 0.6066666666666667
# Accuracy for column cg13520090: 0.6399999999999999
# Accuracy for column cg05538980: 0.62
# Accuracy for column cg18580385: 0.6733333333333333

# %% [markdown]
# # Decision Tree

# %%
output = []
for i in range(1, 101):
    print(i)
    data = CpG_Data.drop('APPRDX', axis=1)
    labels = CpG_Data['APPRDX']
    
    dt_model = DecisionTreeClassifier()
    accuracy_scores = cross_val_score(dt_model, data, labels, cv=10)
    
    mean_accuracy = accuracy_scores.mean()
    print(f'Accuracy: {mean_accuracy}')
    output.append(mean_accuracy)

np.savetxt("All5_Top50sCpG_Female_100DecisionTree.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.6333333333333332
# 2
# Accuracy: 0.6399999999999999
# 3
# Accuracy: 0.6266666666666667
# 4
# Accuracy: 0.6466666666666667
# 5
# Accuracy: 0.64
# 6
# Accuracy: 0.6666666666666667
# 7
# Accuracy: 0.5933333333333334
# 8
# Accuracy: 0.6333333333333334
# 9
# Accuracy: 0.6266666666666667
# 10
# Accuracy: 0.6599999999999999
# 11
# Accuracy: 0.6333333333333333
# 12
# Accuracy: 0.6133333333333333
# 13
# Accuracy: 0.6333333333333334
# 14
# Accuracy: 0.6533333333333333
# 15
# Accuracy: 0.6199999999999999
# 16
# Accuracy: 0.64
# 17
# Accuracy: 0.6199999999999999
# 18
# Accuracy: 0.6399999999999999
# 19
# Accuracy: 0.6666666666666667
# 20
# Accuracy: 0.6533333333333333
# 21
# Accuracy: 0.6533333333333333
# 22
# Accuracy: 0.6333333333333333
# 23
# Accuracy: 0.6399999999999999
# 24
# Accuracy: 0.6466666666666667
# 25
# Accuracy: 0.6133333333333333
# 26
# Accuracy: 0.64
# 27
# Accuracy: 0.64
# 28
# Accuracy: 0.6333333333333333
# 29
# Accuracy: 0.66
# 30
# Accuracy: 0.6333333333333333
# 31
# Accuracy: 0.6599999999999999
# 32
# Accuracy: 0.6399999999999999
# 33
# Accuracy: 0.6399999999999999
# 34
# Accuracy: 0.6266666666666666
# 35
# Accuracy: 0.6066666666666667
# 36
# Accuracy: 0.6266666666666667
# 37
# Accuracy: 0.6266666666666667
# 38
# Accuracy: 0.6133333333333333
# 39
# Accuracy: 0.6333333333333333
# 40
# Accuracy: 0.6799999999999999
# 41
# Accuracy: 0.6666666666666667
# 42
# Accuracy: 0.6266666666666667
# 43
# Accuracy: 0.6066666666666667
# 44
# Accuracy: 0.6133333333333333
# 45
# Accuracy: 0.68
# 46
# Accuracy: 0.62
# 47
# Accuracy: 0.6333333333333333
# 48
# Accuracy: 0.6466666666666667
# 49
# Accuracy: 0.6400000000000001
# 50
# Accuracy: 0.64
# 51
# Accuracy: 0.6466666666666667
# 52
# Accuracy: 0.6266666666666667
# 53
# Accuracy: 0.66
# 54
# Accuracy: 0.64
# 55
# Accuracy: 0.6666666666666666
# 56
# Accuracy: 0.6133333333333334
# 57
# Accuracy: 0.64
# 58
# Accuracy: 0.6533333333333333
# 59
# Accuracy: 0.6333333333333332
# 60
# Accuracy: 0.6066666666666667
# 61
# Accuracy: 0.6199999999999999
# 62
# Accuracy: 0.6333333333333333
# 63
# Accuracy: 0.6333333333333333
# 64
# Accuracy: 0.6466666666666667
# 65
# Accuracy: 0.66
# 66
# Accuracy: 0.6533333333333333
# 67
# Accuracy: 0.6399999999999999
# 68
# Accuracy: 0.6866666666666666
# 69
# Accuracy: 0.64
# 70
# Accuracy: 0.6266666666666666
# 71
# Accuracy: 0.6333333333333334
# 72
# Accuracy: 0.6733333333333332
# 73
# Accuracy: 0.6466666666666667
# 74
# Accuracy: 0.6266666666666667
# 75
# Accuracy: 0.5933333333333333
# 76
# Accuracy: 0.6733333333333332
# 77
# Accuracy: 0.6066666666666667
# 78
# Accuracy: 0.6666666666666667
# 79
# Accuracy: 0.6133333333333333
# 80
# Accuracy: 0.6133333333333333
# 81
# Accuracy: 0.6333333333333333
# 82
# Accuracy: 0.6266666666666666
# 83
# Accuracy: 0.6733333333333333
# 84
# Accuracy: 0.6266666666666667
# 85
# Accuracy: 0.64
# 86
# Accuracy: 0.6399999999999999
# 87
# Accuracy: 0.6666666666666667
# 88
# Accuracy: 0.6466666666666667
# 89
# Accuracy: 0.6333333333333334
# 90
# Accuracy: 0.6333333333333333
# 91
# Accuracy: 0.5866666666666667
# 92
# Accuracy: 0.6333333333333333
# 93
# Accuracy: 0.6333333333333333
# 94
# Accuracy: 0.6533333333333333
# 95
# Accuracy: 0.62
# 96
# Accuracy: 0.6866666666666666
# 97
# Accuracy: 0.6533333333333334
# 98
# Accuracy: 0.6399999999999999
# 99
# Accuracy: 0.6466666666666667
# 100
# Accuracy: 0.6266666666666667

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                                                CpG_Data['APPRDX'], test_size=0.2)
        
        dt_model = DecisionTreeClassifier()
        dt_model.fit(train_data, train_labels)
        
        predictions = dt_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_DecTree.csv", output, delimiter=",")
        joblib.dump(dt_model, f"{col}_DecTree_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.6333333333333333
# Accuracy for column cg04983473: 0.7666666666666667
# Accuracy for column cg25943702: 0.7
# Accuracy for column cg01620849: 0.4666666666666667
# Accuracy for column cg22210403: 0.6666666666666666
# Accuracy for column cg21241862: 0.4666666666666667
# Accuracy for column cg19030090: 0.5
# Accuracy for column cg02232418: 0.5
# Accuracy for column cg18757169: 0.7333333333333333
# Accuracy for column cg02992048: 0.7
# Accuracy for column cg22810281: 0.6333333333333333
# Accuracy for column cg17780657: 0.6666666666666666
# Accuracy for column cg20230179: 0.6666666666666666
# Accuracy for column cg24573261: 0.7333333333333333
# Accuracy for column cg08497332: 0.7333333333333333
# Accuracy for column cg15442746: 0.6333333333333333
# Accuracy for column cg23641264: 0.7
# Accuracy for column cg13002109: 0.6
# Accuracy for column cg10848291: 0.7
# Accuracy for column cg07010694: 0.6666666666666666
# Accuracy for column cg18281829: 0.6333333333333333
# Accuracy for column cg06977831: 0.5
# Accuracy for column cg24576735: 0.7666666666666667
# Accuracy for column cg06017944: 0.6666666666666666
# Accuracy for column cg12077460: 0.7333333333333333
# Accuracy for column cg03929615: 0.6333333333333333
# Accuracy for column cg01686420: 0.6666666666666666
# Accuracy for column cg16308148: 0.6333333333333333
# Accuracy for column cg09733916: 0.7666666666666667
# Accuracy for column cg25844977: 0.7
# Accuracy for column cg08369141: 0.7333333333333333
# Accuracy for column cg25823996: 0.6333333333333333
# Accuracy for column cg05015348: 0.7
# Accuracy for column cg14074878: 0.7333333333333333
# Accuracy for column cg24752563: 0.7
# Accuracy for column cg10644659: 0.8333333333333334
# Accuracy for column cg06512164: 0.6666666666666666
# Accuracy for column cg10387956: 0.6
# Accuracy for column cg25696758: 0.7333333333333333
# Accuracy for column cg08592683: 0.6
# Accuracy for column cg05226711: 0.5333333333333333
# Accuracy for column cg24282845: 0.6
# Accuracy for column cg27262702: 0.7333333333333333
# Accuracy for column cg16919248: 0.5333333333333333
# Accuracy for column cg02488409: 0.5666666666666667
# Accuracy for column cg23142730: 0.8333333333333334
# Accuracy for column cg02888917: 0.8
# Accuracy for column cg27486833: 0.7333333333333333
# Accuracy for column cg26730369: 0.6
# Accuracy for column cg11686092: 0.6666666666666666
# Accuracy for column cg14149699: 0.7666666666666667
# Accuracy for column cg25380030: 0.6666666666666666
# Accuracy for column cg27625479: 0.6
# Accuracy for column cg10205430: 0.5666666666666667
# Accuracy for column cg03458463: 0.6333333333333333
# Accuracy for column cg23187886: 0.6333333333333333
# Accuracy for column cg22930773: 0.7666666666666667
# Accuracy for column cg05769889: 0.7333333333333333
# Accuracy for column cg14385965: 0.6
# Accuracy for column cg19441674: 0.6
# Accuracy for column cg20170632: 0.6666666666666666
# Accuracy for column cg25114899: 0.43333333333333335
# Accuracy for column cg27129641: 0.7333333333333333
# Accuracy for column cg26704870: 0.5333333333333333
# Accuracy for column cg04221681: 0.6
# Accuracy for column cg23690866: 0.5666666666666667
# Accuracy for column cg03817303: 0.6
# Accuracy for column cg14612428: 0.7333333333333333
# Accuracy for column cg09837559: 0.6333333333333333
# Accuracy for column cg06620193: 0.6666666666666666
# Accuracy for column cg09368832: 0.6666666666666666
# Accuracy for column cg17196875: 0.6333333333333333
# Accuracy for column cg11943389: 0.5
# Accuracy for column cg09602742: 0.5333333333333333
# Accuracy for column cg25578728: 0.6
# Accuracy for column cg00346755: 0.7
# Accuracy for column cg21379625: 0.7333333333333333
# Accuracy for column cg06310816: 0.6333333333333333
# Accuracy for column cg09901201: 0.7333333333333333
# Accuracy for column cg19320612: 0.5666666666666667
# Accuracy for column cg01869632: 0.6
# Accuracy for column cg03573792: 0.4666666666666667
# Accuracy for column cg14548871: 0.7666666666666667
# Accuracy for column cg04721557: 0.6
# Accuracy for column cg17218282: 0.6
# Accuracy for column cg20471798: 0.5333333333333333
# Accuracy for column cg04948892: 0.7
# Accuracy for column cg12751142: 0.6666666666666666
# Accuracy for column cg17957325: 0.5333333333333333
# Accuracy for column cg13520090: 0.7
# Accuracy for column cg05538980: 0.5666666666666667
# Accuracy for column cg18580385: 0.6333333333333333

# %% [markdown]
# # Random Forest

# %%
output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    random_forest_model = RandomForestClassifier(n_estimators=100, max_depth=5)
    scores = cross_val_score(random_forest_model, X, y, cv=10)
    mean_score = scores.mean()
    print(f'Mean accuracy: {mean_score}')
# 74
# Mean accuracy: 0.7733333333333332
# 75
# Mean accuracy: 0.7733333333333332
# 76
# Mean accuracy: 0.7466666666666667
# 77
# Mean accuracy: 0.76
# 78
# Mean accuracy: 0.76
# 79
# Mean accuracy: 0.7666666666666666
# 80
# Mean accuracy: 0.7866666666666667
# 81
# Mean accuracy: 0.7733333333333333
# 82
# Mean accuracy: 0.7933333333333332
# 83
# Mean accuracy: 0.7466666666666667
# 84
# Mean accuracy: 0.7533333333333333
# 85
# Mean accuracy: 0.7733333333333333
# 86
# Mean accuracy: 0.7666666666666667
# 87
# Mean accuracy: 0.7733333333333333
# 88
# Mean accuracy: 0.7733333333333333
# 89
# Mean accuracy: 0.7866666666666666
# 90
# Mean accuracy: 0.7666666666666666
# 91
# Mean accuracy: 0.7666666666666666
# 92
# Mean accuracy: 0.7799999999999999
# 93
# Mean accuracy: 0.7533333333333333
# 94
# Mean accuracy: 0.7466666666666666
# 95
# Mean accuracy: 0.7666666666666666
# 96
# Mean accuracy: 0.76
# 97
# Mean accuracy: 0.7466666666666667
# 98
# Mean accuracy: 0.7666666666666666
# 99
# Mean accuracy: 0.7533333333333333
# 100
# Mean accuracy: 0.7666666666666666

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                        CpG_Data['APPRDX'], test_size=0.2)
        
        random_forest_model = RandomForestClassifier(n_estimators=100, max_depth=5)
        random_forest_model.fit(train_data, train_labels)
        
        predictions = random_forest_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_RF.csv", output, delimiter=",")
        joblib.dump(random_forest_model, f"{col}_RF_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.6666666666666666
# Accuracy for column cg04983473: 0.7666666666666667
# Accuracy for column cg25943702: 0.6
# Accuracy for column cg01620849: 0.6666666666666666
# Accuracy for column cg22210403: 0.6333333333333333
# Accuracy for column cg21241862: 0.6666666666666666
# Accuracy for column cg19030090: 0.6666666666666666
# Accuracy for column cg02232418: 0.7666666666666667
# Accuracy for column cg18757169: 0.7
# Accuracy for column cg02992048: 0.8333333333333334
# Accuracy for column cg22810281: 0.8
# Accuracy for column cg17780657: 0.6666666666666666
# Accuracy for column cg20230179: 0.6333333333333333
# Accuracy for column cg24573261: 0.6333333333333333
# Accuracy for column cg08497332: 0.7333333333333333
# Accuracy for column cg15442746: 0.7333333333333333
# Accuracy for column cg23641264: 0.7333333333333333
# Accuracy for column cg13002109: 0.8
# Accuracy for column cg10848291: 0.6666666666666666
# Accuracy for column cg07010694: 0.7
# Accuracy for column cg18281829: 0.8333333333333334
# Accuracy for column cg06977831: 0.6333333333333333
# Accuracy for column cg24576735: 0.5666666666666667
# Accuracy for column cg06017944: 0.8
# Accuracy for column cg12077460: 0.7666666666666667
# Accuracy for column cg03929615: 0.7
# Accuracy for column cg01686420: 0.7333333333333333
# Accuracy for column cg16308148: 0.7
# Accuracy for column cg09733916: 0.7
# Accuracy for column cg25844977: 0.7333333333333333
# Accuracy for column cg08369141: 0.5666666666666667
# Accuracy for column cg25823996: 0.7
# Accuracy for column cg05015348: 0.6666666666666666
# Accuracy for column cg14074878: 0.6
# Accuracy for column cg24752563: 0.5666666666666667
# Accuracy for column cg10644659: 0.8333333333333334
# Accuracy for column cg06512164: 0.7666666666666667
# Accuracy for column cg10387956: 0.8
# Accuracy for column cg25696758: 0.5333333333333333
# Accuracy for column cg08592683: 0.6333333333333333
# Accuracy for column cg05226711: 0.6333333333333333
# Accuracy for column cg24282845: 0.6666666666666666
# Accuracy for column cg27262702: 0.6666666666666666
# Accuracy for column cg16919248: 0.6666666666666666
# Accuracy for column cg02488409: 0.7666666666666667
# Accuracy for column cg23142730: 0.6666666666666666
# Accuracy for column cg02888917: 0.8
# Accuracy for column cg27486833: 0.6333333333333333
# Accuracy for column cg26730369: 0.6333333333333333
# Accuracy for column cg11686092: 0.8
# Accuracy for column cg14149699: 0.7333333333333333
# Accuracy for column cg25380030: 0.5666666666666667
# Accuracy for column cg27625479: 0.7333333333333333
# Accuracy for column cg10205430: 0.7333333333333333
# Accuracy for column cg03458463: 0.6333333333333333
# Accuracy for column cg23187886: 0.6666666666666666
# Accuracy for column cg22930773: 0.7333333333333333
# Accuracy for column cg05769889: 0.8
# Accuracy for column cg14385965: 0.6333333333333333
# Accuracy for column cg19441674: 0.6666666666666666
# Accuracy for column cg20170632: 0.7666666666666667
# Accuracy for column cg25114899: 0.8333333333333334
# Accuracy for column cg27129641: 0.6
# Accuracy for column cg26704870: 0.7
# Accuracy for column cg04221681: 0.7
# Accuracy for column cg23690866: 0.8
# Accuracy for column cg03817303: 0.5333333333333333
# Accuracy for column cg14612428: 0.7
# Accuracy for column cg09837559: 0.5666666666666667
# Accuracy for column cg06620193: 0.6666666666666666
# Accuracy for column cg09368832: 0.7
# Accuracy for column cg17196875: 0.5
# Accuracy for column cg11943389: 0.6666666666666666
# Accuracy for column cg09602742: 0.6666666666666666
# Accuracy for column cg25578728: 0.9
# Accuracy for column cg00346755: 0.7666666666666667
# Accuracy for column cg21379625: 0.6333333333333333
# Accuracy for column cg06310816: 0.6333333333333333
# Accuracy for column cg09901201: 0.5666666666666667
# Accuracy for column cg19320612: 0.7333333333333333
# Accuracy for column cg01869632: 0.7666666666666667
# Accuracy for column cg03573792: 0.6
# Accuracy for column cg14548871: 0.7333333333333333
# Accuracy for column cg04721557: 0.7333333333333333
# Accuracy for column cg17218282: 0.8
# Accuracy for column cg20471798: 0.6333333333333333
# Accuracy for column cg04948892: 0.7333333333333333
# Accuracy for column cg12751142: 0.6666666666666666
# Accuracy for column cg17957325: 0.7
# Accuracy for column cg13520090: 0.7333333333333333
# Accuracy for column cg05538980: 0.7333333333333333
# Accuracy for column cg18580385: 0.7

# %% [markdown]
# # LASSO

# %%
output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    lasso_model = LogisticRegression(penalty='l1', solver='liblinear', max_iter=500)
    parameters = {'C': [0.1, 1, 10, 100]}
    lasso_model = GridSearchCV(lasso_model, parameters)
    lasso_model.fit(X_train, y_train)
    
    cv_scores = cross_val_score(lasso_model, X, y, cv=10)
    mean_cv_score = np.mean(cv_scores)
    print(f'Mean cross-validation accuracy: {mean_cv_score}')
    
    predictions = lasso_model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Test accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100Lasso.csv", output, delimiter=",")
# Out:
# 1
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8
# 2
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 3
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 4
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 5
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 6
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 7
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9666666666666667
# 8
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 9
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 10
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.7
# 11
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 12
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 13
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 14
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 15
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8333333333333334
# 16
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 17
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 18
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 19
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8333333333333334
# 20
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8
# 21
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 22
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 23
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.9333333333333333
# 24
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.9
# 25
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8
# 26
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 27
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 28
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 29
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 30
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8666666666666667
# 31
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 32
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 33
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 34
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 35
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 36
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 37
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 38
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 39
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 40
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 41
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 42
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 43
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 44
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 45
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 46
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 47
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 48
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 49
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 50
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 51
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8333333333333334
# 52
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 53
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8333333333333334
# 54
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 55
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 56
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 57
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 58
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8333333333333334
# 59
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 60
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9666666666666667
# 61
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 62
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 63
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 64
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 65
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8666666666666667
# 66
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 67
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 68
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 69
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 70
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 71
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 72
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 73
# Mean cross-validation accuracy: 0.8133333333333335
# Test accuracy: 0.8
# 74
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 75
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 76
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 77
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.9
# 78
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 79
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 80
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 81
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.6666666666666666
# 82
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 83
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 84
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 85
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9
# 86
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 87
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8666666666666667
# 88
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 89
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 90
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 91
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7666666666666667
# 92
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667
# 93
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8
# 94
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.6666666666666666
# 95
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 96
# Mean cross-validation accuracy: 0.8266666666666668
# Test accuracy: 0.8666666666666667
# 97
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8333333333333334
# 98
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.7333333333333333
# 99
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.9333333333333333
# 100
# Mean cross-validation accuracy: 0.8200000000000001
# Test accuracy: 0.8666666666666667

# %% [markdown]
# output = []
# for i in range(1, 101):
#     print(i)
#     train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1),
#                                                                         CpG_Data['APPRDX'], test_size=0.2)
#
#     lasso_model = LogisticRegression(penalty='l1', solver = 'liblinear', max_iter = 500)
#     parameters = {'C': [0.1, 1, 10, 100]}
#     lasso_model = GridSearchCV(lasso_model, parameters)
#     lasso_model.fit(train_data, train_labels)
#
#
#     predictions = lasso_model.predict(test_data)
#     accuracy = accuracy_score(test_labels, predictions)
#     print(f'Accuracy: {accuracy}')
#     output.append(accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100Lasso.csv", output, delimiter=",")

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], CpG_Data['APPRDX'], 
                                                                            test_size=0.2)

        lasso_model = LogisticRegression(penalty='l1', solver = 'liblinear', max_iter = 1000)
        parameters = {'C': [0.1, 1, 10, 100]}
        lasso_model = GridSearchCV(lasso_model, parameters)
        lasso_model.fit(train_data, train_labels)

        predictions = lasso_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
# Accuracy for column cg26704870: 0.7
# Accuracy for column cg04221681: 0.7333333333333333
# Accuracy for column cg23690866: 0.5666666666666667
# Accuracy for column cg03817303: 0.7666666666666667
# Accuracy for column cg14612428: 0.7666666666666667
# Accuracy for column cg09837559: 0.7666666666666667
# Accuracy for column cg06620193: 0.8
# Accuracy for column cg09368832: 0.6666666666666666
# Accuracy for column cg17196875: 0.8
# Accuracy for column cg11943389: 0.8333333333333334
# Accuracy for column cg09602742: 0.7666666666666667
# Accuracy for column cg25578728: 0.6666666666666666
# Accuracy for column cg00346755: 0.8333333333333334
# Accuracy for column cg21379625: 0.6333333333333333
# Accuracy for column cg06310816: 0.7666666666666667
# Accuracy for column cg09901201: 0.8
# Accuracy for column cg19320612: 0.6333333333333333
# Accuracy for column cg01869632: 0.8333333333333334
# Accuracy for column cg03573792: 0.7333333333333333
# Accuracy for column cg14548871: 0.7
# Accuracy for column cg04721557: 0.6666666666666666
# Accuracy for column cg17218282: 0.6666666666666666
# Accuracy for column cg20471798: 0.8
# Accuracy for column cg04948892: 0.7333333333333333
# Accuracy for column cg12751142: 0.7666666666666667
# Accuracy for column cg17957325: 0.7666666666666667
# Accuracy for column cg13520090: 0.7333333333333333
# Accuracy for column cg05538980: 0.7333333333333333
# Accuracy for column cg18580385: 0.8333333333333334

# %% [markdown]
# # Elastic Net

# %%
output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    enet_model = LogisticRegression(penalty='elasticnet', solver='saga', max_iter=10000, l1_ratio=0.5)
    parameters = {'C': [0.1, 1, 10, 100]}
    enet_model = GridSearchCV(enet_model, parameters)
    enet_model.fit(X_train, y_train)
    
    cv_scores = cross_val_score(enet_model, X, y, cv=10)
    mean_cv_score = np.mean(cv_scores)
    print(f'Mean cross-validation accuracy: {mean_cv_score}')
    
    predictions = enet_model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Test accuracy: {accuracy}')
    output.append(accuracy)
    
np.savetxt("All5_Top50sCpG_Female_100ElasticNet.csv", output, delimiter=",")
# Out:
# 1
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 2
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 3
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 4
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 5
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 6
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 7
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 8
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7333333333333333
# 9
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 10
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 11
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 12
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 13
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 14
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9666666666666667
# 15
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 16
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 17
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 18
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 19
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 20
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 21
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 22
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 23
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 24
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 25
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 26
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 27
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 28
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 29
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 30
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 31
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 32
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 33
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 34
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 35
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 36
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 37
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 38
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 39
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 40
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 41
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 42
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 43
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 44
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 45
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 46
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 47
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 48
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 49
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 50
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 51
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 52
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 53
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 54
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 55
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 56
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 57
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 58
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 59
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 60
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 61
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 62
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 63
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 64
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 65
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 66
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 67
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 68
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 69
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 70
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 71
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 72
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 73
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 74
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 75
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7333333333333333
# 76
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 77
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 78
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.7666666666666667
# 79
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 80
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 81
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 82
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 83
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 84
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 85
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 86
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 87
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 88
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 89
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 90
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 91
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 92
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 93
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 94
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9
# 95
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 96
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8
# 97
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8333333333333334
# 98
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.9333333333333333
# 99
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667
# 100
# Mean cross-validation accuracy: 0.8066666666666666
# Test accuracy: 0.8666666666666667

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], CpG_Data['APPRDX'], 
                                                                            test_size=0.2)

        enet_model = LogisticRegression(penalty='elasticnet', solver='saga', max_iter=10000, l1_ratio=0.5)
        parameters = {'C': [0.1, 1, 10, 100]}
        enet_model = GridSearchCV(enet_model, parameters)
        enet_model.fit(train_data, train_labels)
        
        predictions = enet_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_enet.csv", output, delimiter=",")
        joblib.dump(enet_model, f"{col}_enet_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.7
# Accuracy for column cg04983473: 0.7
# Accuracy for column cg25943702: 0.7333333333333333
# Accuracy for column cg01620849: 0.8
# Accuracy for column cg22210403: 0.5666666666666667
# Accuracy for column cg21241862: 0.8
# Accuracy for column cg19030090: 0.6
# Accuracy for column cg02232418: 0.8333333333333334
# Accuracy for column cg18757169: 0.7666666666666667
# Accuracy for column cg02992048: 0.8
# Accuracy for column cg22810281: 0.8666666666666667
# Accuracy for column cg17780657: 0.6666666666666666
# Accuracy for column cg20230179: 0.7
# Accuracy for column cg24573261: 0.7
# Accuracy for column cg08497332: 0.7333333333333333
# Accuracy for column cg15442746: 0.6666666666666666
# Accuracy for column cg23641264: 0.7333333333333333
# Accuracy for column cg13002109: 0.9666666666666667
# Accuracy for column cg10848291: 0.6666666666666666
# Accuracy for column cg07010694: 0.6333333333333333
# Accuracy for column cg18281829: 0.7
# Accuracy for column cg06977831: 0.7666666666666667
# Accuracy for column cg24576735: 0.7666666666666667
# Accuracy for column cg06017944: 0.8
# Accuracy for column cg12077460: 0.8333333333333334
# Accuracy for column cg03929615: 0.6
# Accuracy for column cg01686420: 0.7
# Accuracy for column cg16308148: 0.7666666666666667
# Accuracy for column cg09733916: 0.8
# Accuracy for column cg25844977: 0.8
# Accuracy for column cg08369141: 0.7666666666666667
# Accuracy for column cg25823996: 0.7333333333333333
# Accuracy for column cg05015348: 0.7666666666666667
# Accuracy for column cg18497960: 0.6333333333333333
# Accuracy for column cg18830699: 0.7666666666666667
# Accuracy for column cg18319799: 0.7
# Accuracy for column cg04954056: 0.6666666666666666
# Accuracy for column cg09902448: 0.7333333333333333
# Accuracy for column cg00319242: 0.7
# Accuracy for column cg05125128: 0.6
# Accuracy for column cg26819590: 0.8666666666666667
# Accuracy for column cg14587401: 0.7666666666666667
# Accuracy for column cg06191029: 0.6333333333333333
# Accuracy for column cg14270890: 0.7
# Accuracy for column cg22237213: 0.6333333333333333
# Accuracy for column cg06630567: 0.7
# Accuracy for column cg26856497: 0.8666666666666667
# Accuracy for column cg23565749: 0.7333333333333333
# Accuracy for column cg12413242: 0.7
# Accuracy for column cg24784310: 0.7
# Accuracy for column cg04359365: 0.7
# Accuracy for column cg00265238: 0.7333333333333333
# Accuracy for column cg21877355: 0.8333333333333334
# Accuracy for column cg05769889: 0.8
# Accuracy for column cg14385965: 0.7333333333333333
# Accuracy for column cg19441674: 0.6666666666666666
# Accuracy for column cg20170632: 0.7
# Accuracy for column cg25114899: 0.7333333333333333
# Accuracy for column cg27129641: 0.7
# Accuracy for column cg26704870: 0.7333333333333333
# Accuracy for column cg04221681: 0.7666666666666667
# Accuracy for column cg23690866: 0.7
# Accuracy for column cg03817303: 0.8
# Accuracy for column cg14612428: 0.8333333333333334
# Accuracy for column cg09837559: 0.7333333333333333
# Accuracy for column cg06620193: 0.7333333333333333
# Accuracy for column cg09368832: 0.7333333333333333
# Accuracy for column cg17196875: 0.7666666666666667
# Accuracy for column cg11943389: 0.7333333333333333
# Accuracy for column cg09602742: 0.8666666666666667
# Accuracy for column cg25578728: 0.6666666666666666
# Accuracy for column cg00346755: 0.7333333333333333
# Accuracy for column cg21379625: 0.8333333333333334
# Accuracy for column cg06310816: 0.6666666666666666
# Accuracy for column cg09901201: 0.7333333333333333
# Accuracy for column cg19320612: 0.8333333333333334
# Accuracy for column cg01869632: 0.7666666666666667
# Accuracy for column cg03573792: 0.6666666666666666
# Accuracy for column cg14548871: 0.7
# Accuracy for column cg04721557: 0.7
# Accuracy for column cg17218282: 0.6333333333333333
# Accuracy for column cg20471798: 0.8
# Accuracy for column cg04948892: 0.7
# Accuracy for column cg12751142: 0.7666666666666667
# Accuracy for column cg17957325: 0.7
# Accuracy for column cg13520090: 0.7666666666666667
# Accuracy for column cg05538980: 0.8
# Accuracy for column cg18580385: 0.7666666666666667

# %% [markdown]
# # SGD Classifier

# %%
output = []
for i in range(1, 101):
    print(i)
    skf = StratifiedKFold(n_splits=10, shuffle=True)
    accuracies = []
    
    for train_index, test_index in skf.split(CpG_Data.drop('APPRDX', axis=1), CpG_Data['APPRDX']):
        train_data, test_data = CpG_Data.drop('APPRDX', axis=1).iloc[train_index], CpG_Data.drop('APPRDX', axis=1).iloc[test_index]
        train_labels, test_labels = CpG_Data['APPRDX'].iloc[train_index], CpG_Data['APPRDX'].iloc[test_index]

        sgd_model = SGDClassifier(loss='log', max_iter=10000)
        parameters = {'alpha': [0.0001, 0.001, 0.01, 0.1, 1], 'penalty': ['l1', 'l2', 'elasticnet']}
        sgd_model = GridSearchCV(sgd_model, parameters)
        sgd_model.fit(train_data, train_labels)

        predictions = sgd_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        accuracies.append(accuracy)

    avg_accuracy = sum(accuracies)/len(accuracies)
    print(f'Average accuracy: {avg_accuracy}')
    output.append(avg_accuracy)

np.savetxt("All5_Top50sCpG_Female_100sgd.csv", output, delimiter=",")
# Out:
# 1
# Average accuracy: 0.7933333333333333
# 2
# Average accuracy: 0.7266666666666668
# 3
# Average accuracy: 0.7866666666666667
# 4
# Average accuracy: 0.7866666666666667
# 5
# Average accuracy: 0.8
# 6
# Average accuracy: 0.7666666666666667
# 7
# Average accuracy: 0.7866666666666665
# 8
# Average accuracy: 0.82
# 9
# Average accuracy: 0.7266666666666667
# 10
# Average accuracy: 0.7533333333333333
# 11
# Average accuracy: 0.76
# 87
# Average accuracy: 0.8133333333333332
# 88
# Average accuracy: 0.7333333333333333
# 89
# Average accuracy: 0.6666666666666667
# 90
# Average accuracy: 0.8
# 91
# Average accuracy: 0.7933333333333333
# 92
# Average accuracy: 0.7866666666666666
# 93
# Average accuracy: 0.7533333333333333
# 94
# Average accuracy: 0.78
# 95
# Average accuracy: 0.7533333333333334
# 96
# Average accuracy: 0.78
# 97
# Average accuracy: 0.7533333333333333
# 98
# Average accuracy: 0.7866666666666667
# 99
# Average accuracy: 0.8133333333333332
# 100
# Average accuracy: 0.8066666666666666

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                        CpG_Data['APPRDX'], test_size=0.2)
        
        sgd_model = SGDClassifier(loss='log', max_iter=10000)
        parameters = {'alpha': [0.0001, 0.001, 0.01, 0.1, 1], 'penalty': ['l1', 'l2', 'elasticnet']}
        sgd_model = GridSearchCV(sgd_model, parameters)
        sgd_model.fit(train_data, train_labels)

        predictions = sgd_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_SGD.csv", output, delimiter=",")
        joblib.dump(sgd_model, f"{col}_sgd_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.7
# Accuracy for column cg04983473: 0.8
# Accuracy for column cg25943702: 0.7
# Accuracy for column cg01620849: 0.6
# Accuracy for column cg22210403: 0.8666666666666667
# Accuracy for column cg21241862: 0.8333333333333334
# Accuracy for column cg19030090: 0.7333333333333333
# Accuracy for column cg02232418: 0.8
# Accuracy for column cg18757169: 0.8
# Accuracy for column cg02992048: 0.8666666666666667
# Accuracy for column cg22810281: 0.23333333333333334
# Accuracy for column cg17780657: 0.7666666666666667
# Accuracy for column cg20230179: 0.7333333333333333
# Accuracy for column cg24573261: 0.8
# Accuracy for column cg08497332: 0.6333333333333333
# Accuracy for column cg15442746: 0.7333333333333333
# Accuracy for column cg23641264: 0.7
# Accuracy for column cg13002109: 0.7666666666666667
# Accuracy for column cg10848291: 0.6666666666666666
# Accuracy for column cg07010694: 0.8
# Accuracy for column cg18281829: 0.7666666666666667
# Accuracy for column cg06977831: 0.8
# Accuracy for column cg24576735: 0.7
# Accuracy for column cg06017944: 0.7
# Accuracy for column cg12077460: 0.8333333333333334
# Accuracy for column cg03929615: 0.8
# Accuracy for column cg01686420: 0.7333333333333333
# Accuracy for column cg16308148: 0.6666666666666666
# Accuracy for column cg09733916: 0.8333333333333334
# Accuracy for column cg25844977: 0.6333333333333333
# Accuracy for column cg08369141: 0.3
# Accuracy for column cg25823996: 0.6
# Accuracy for column cg05015348: 0.6666666666666666
# Accuracy for column cg18497960: 0.3
# Accuracy for column cg18830699: 0.7666666666666667
# Accuracy for column cg18319799: 0.8666666666666667
# Accuracy for column cg04954056: 0.8
# Accuracy for column cg09902448: 0.7333333333333333
# Accuracy for column cg00319242: 0.6333333333333333
# Accuracy for column cg05125128: 0.7666666666666667
# Accuracy for column cg26819590: 0.6333333333333333
# Accuracy for column cg14587401: 0.7333333333333333
# Accuracy for column cg06191029: 0.7333333333333333
# Accuracy for column cg14270890: 0.7666666666666667
# Accuracy for column cg23142730: 0.6666666666666666
# Accuracy for column cg02888917: 0.7666666666666667
# Accuracy for column cg27486833: 0.7333333333333333
# Accuracy for column cg26730369: 0.8666666666666667
# Accuracy for column cg11686092: 0.7333333333333333
# Accuracy for column cg14149699: 0.8
# Accuracy for column cg25380030: 0.6333333333333333
# Accuracy for column cg27625479: 0.7666666666666667
# Accuracy for column cg10205430: 0.7666666666666667
# Accuracy for column cg03458463: 0.6
# Accuracy for column cg23187886: 0.6666666666666666
# Accuracy for column cg22930773: 0.8
# Accuracy for column cg05769889: 0.8
# Accuracy for column cg14385965: 0.7666666666666667
# Accuracy for column cg19441674: 0.6666666666666666
# Accuracy for column cg20170632: 0.6666666666666666
# Accuracy for column cg25114899: 0.7333333333333333
# Accuracy for column cg27129641: 0.7
# Accuracy for column cg26704870: 0.7333333333333333
# Accuracy for column cg04221681: 0.5666666666666667
# Accuracy for column cg23690866: 0.7333333333333333
# Accuracy for column cg03817303: 0.9
# Accuracy for column cg14612428: 0.7666666666666667
# Accuracy for column cg09837559: 0.26666666666666666
# Accuracy for column cg06620193: 0.7333333333333333
# Accuracy for column cg09368832: 0.7333333333333333
# Accuracy for column cg17196875: 0.6666666666666666
# Accuracy for column cg11943389: 0.8
# Accuracy for column cg09602742: 0.7
# Accuracy for column cg25578728: 0.7
# Accuracy for column cg00346755: 0.8
# Accuracy for column cg21379625: 0.6333333333333333
# Accuracy for column cg06310816: 0.8666666666666667
# Accuracy for column cg09901201: 0.3
# Accuracy for column cg19320612: 0.8333333333333334
# Accuracy for column cg01869632: 0.7333333333333333
# Accuracy for column cg03573792: 0.8666666666666667
# Accuracy for column cg14548871: 0.8333333333333334
# Accuracy for column cg04721557: 0.7333333333333333
# Accuracy for column cg17218282: 0.6666666666666666
# Accuracy for column cg20471798: 0.7333333333333333
# Accuracy for column cg04948892: 0.6666666666666666
# Accuracy for column cg12751142: 0.8
# Accuracy for column cg17957325: 0.7
# Accuracy for column cg13520090: 0.7666666666666667
# Accuracy for column cg05538980: 0.7
# Accuracy for column cg18580385: 0.8333333333333334

# %% [markdown]
# # SVM

# %% [markdown]
# ## SVM Linear

# %% [markdown]
# output = []
# for i in range(1, 101):
#     print(i)
#     data = CpG_Data.drop('APPRDX', axis=1)
#     labels = CpG_Data['APPRDX']
#     svm_model = SVC(kernel='linear')
#     parameters = {'C': [0.01, 0.1, 0.5, 1, 10, 50, 100]}
#     svm_model = GridSearchCV(svm_model, parameters)
#     scores = cross_val_score(svm_model, data, labels, cv=10)
#     accuracy = np.mean(scores)
#     print(f'Accuracy: {accuracy}')
#     output.append(accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100svmL.csv", output, delimiter=",")

# %%
output = []
for i in range(1, 101):
    print(i)
    train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1), 
                                                                        CpG_Data['APPRDX'], test_size=0.2)
    
    svm_model = SVC(kernel='linear')
    parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100]}
    svm_model = GridSearchCV(svm_model, parameters)
    svm_model.fit(train_data, train_labels)
    
    predictions = svm_model.predict(test_data)
    accuracy = accuracy_score(test_labels, predictions)
    print(f'Accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100svmL.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.8666666666666667
# 2
# Accuracy: 0.7666666666666667
# 3
# Accuracy: 0.8
# 4
# Accuracy: 0.8333333333333334
# 5
# Accuracy: 0.8333333333333334
# 6
# Accuracy: 0.8666666666666667
# 7
# Accuracy: 0.8666666666666667
# 8
# Accuracy: 0.8666666666666667
# 9
# Accuracy: 0.8333333333333334
# 10
# Accuracy: 0.8666666666666667
# 11
# Accuracy: 0.8
# 12
# Accuracy: 0.8333333333333334
# 13
# Accuracy: 0.8333333333333334
# 14
# Accuracy: 0.7666666666666667
# 15
# Accuracy: 0.8666666666666667
# 16
# Accuracy: 0.8666666666666667
# 17
# Accuracy: 0.9
# 18
# Accuracy: 0.9
# 19
# Accuracy: 0.8666666666666667
# 20
# Accuracy: 0.9
# 21
# Accuracy: 0.8666666666666667
# 22
# Accuracy: 0.7666666666666667
# 23
# Accuracy: 0.9333333333333333
# 24
# Accuracy: 0.8666666666666667
# 25
# Accuracy: 0.8333333333333334
# 26
# Accuracy: 0.8
# 27
# Accuracy: 0.8
# 28
# Accuracy: 0.8
# 29
# Accuracy: 0.9333333333333333
# 30
# Accuracy: 0.8333333333333334
# 31
# Accuracy: 0.8
# 32
# Accuracy: 0.9333333333333333
# 33
# Accuracy: 0.9
# 34
# Accuracy: 0.8
# 35
# Accuracy: 0.9
# 36
# Accuracy: 0.8
# 37
# Accuracy: 0.9333333333333333
# 38
# Accuracy: 0.8333333333333334
# 39
# Accuracy: 0.9
# 40
# Accuracy: 0.8666666666666667
# 41
# Accuracy: 0.9
# 42
# Accuracy: 0.8333333333333334
# 43
# Accuracy: 0.6666666666666666
# 44
# Accuracy: 0.8333333333333334
# 45
# Accuracy: 0.9333333333333333
# 46
# Accuracy: 0.8333333333333334
# 47
# Accuracy: 0.8666666666666667
# 48
# Accuracy: 0.7666666666666667
# 49
# Accuracy: 0.8666666666666667
# 50
# Accuracy: 0.9666666666666667
# 51
# Accuracy: 0.8
# 52
# Accuracy: 0.7666666666666667
# 53
# Accuracy: 0.7666666666666667
# 54
# Accuracy: 0.7333333333333333
# 55
# Accuracy: 0.9333333333333333
# 56
# Accuracy: 0.9333333333333333
# 57
# Accuracy: 0.8666666666666667
# 58
# Accuracy: 0.8
# 59
# Accuracy: 0.8666666666666667
# 60
# Accuracy: 0.8
# 61
# Accuracy: 0.8333333333333334
# 62
# Accuracy: 0.7666666666666667
# 63
# Accuracy: 0.8333333333333334
# 64
# Accuracy: 0.8
# 65
# Accuracy: 0.7666666666666667
# 66
# Accuracy: 0.9
# 67
# Accuracy: 0.7333333333333333
# 68
# Accuracy: 0.9
# 69
# Accuracy: 0.8
# 70
# Accuracy: 0.7666666666666667
# 71
# Accuracy: 0.8666666666666667
# 72
# Accuracy: 0.7666666666666667
# 73
# Accuracy: 0.9
# 74
# Accuracy: 0.8666666666666667
# 75
# Accuracy: 0.7666666666666667
# 76
# Accuracy: 0.8666666666666667
# 77
# Accuracy: 0.8
# 78
# Accuracy: 0.8333333333333334
# 79
# Accuracy: 0.8666666666666667
# 80
# Accuracy: 0.8
# 81
# Accuracy: 0.8333333333333334
# 82
# Accuracy: 0.8666666666666667
# 83
# Accuracy: 0.8333333333333334
# 84
# Accuracy: 0.8333333333333334
# 85
# Accuracy: 0.8
# 86
# Accuracy: 0.9666666666666667
# 87
# Accuracy: 0.8333333333333334
# 88
# Accuracy: 0.9666666666666667
# 89
# Accuracy: 0.9
# 90
# Accuracy: 0.8
# 91
# Accuracy: 0.8333333333333334
# 92
# Accuracy: 0.8666666666666667
# 93
# Accuracy: 0.9
# 94
# Accuracy: 0.8666666666666667
# 95
# Accuracy: 0.8333333333333334
# 96
# Accuracy: 0.9
# 97
# Accuracy: 0.8666666666666667
# 98
# Accuracy: 0.8
# 99
# Accuracy: 0.8
# 100
# Accuracy: 0.8333333333333334

# %% [markdown]
# In this line of code, the parameters dictionary is being defined. It contains the hyperparameters for the linear SVM model that will be passed to the GridSearchCV function.
#
# The hyperparameter C determines the trade-off between achieving a low training error and a low testing error. In this case, C is set to [1], which means the value of C will be searched for only once, i.e., C=1. C is a regularization parameter, and a smaller value of C will result in a wider margin, while a larger value of C will result in a narrower margin but potentially better classification.
#
#     parameters = {'C': [0.1, 0.5, 1, 5, 10, 50, 100]}
#
# This will test the SVM model with C values of 0.1, 0.5, 1, 5, 10, 50, and 100. The GridSearchCV function will search for the best C value among these values, based on the accuracy of the predictions on the test data.
#
# Note that the larger the value of C, the more the model will try to avoid misclassifying any instances in the training set. On the other hand, a smaller value of C will result in a wider margin, and the model will have a higher tolerance for misclassified instances.

# %% [markdown]
# ### Individual Features

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                        CpG_Data['APPRDX'], test_size=0.2)
        
        svm_model = SVC(kernel='linear')
        parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100]}
        svm_model = GridSearchCV(svm_model, parameters)
        svm_model.fit(train_data, train_labels)

        predictions = svm_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_svmL.csv", output, delimiter=",")
        joblib.dump(svm_model, f"{col}_svmL_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.7666666666666667
# Accuracy for column cg04983473: 0.7
# Accuracy for column cg25943702: 0.8
# Accuracy for column cg01620849: 0.6333333333333333
# Accuracy for column cg22210403: 0.6666666666666666
# Accuracy for column cg21241862: 0.7333333333333333
# Accuracy for column cg19030090: 0.7666666666666667
# Accuracy for column cg02232418: 0.7333333333333333
# Accuracy for column cg18757169: 0.7666666666666667
# Accuracy for column cg02992048: 0.6666666666666666
# Accuracy for column cg22810281: 0.7
# Accuracy for column cg17780657: 0.7333333333333333
# Accuracy for column cg20230179: 0.7
# Accuracy for column cg24573261: 0.6666666666666666
# Accuracy for column cg08497332: 0.7333333333333333
# Accuracy for column cg15442746: 0.8
# Accuracy for column cg04948892: 0.7666666666666667
# Accuracy for column cg12751142: 0.8333333333333334
# Accuracy for column cg17957325: 0.7333333333333333
# Accuracy for column cg13520090: 0.7
# Accuracy for column cg05538980: 0.6333333333333333
# Accuracy for column cg18580385: 0.8

# %% [markdown]
# ## SVM Radial

# %% [markdown]
# ### All Features

# %%
output = []
for i in range(1, 101):
    print(i)
    train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1), 
                                                                        CpG_Data['APPRDX'], test_size=0.2)
    
    svm_model = SVC(kernel='rbf')
    parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100], 'gamma': [0.01, 0.1, 1, 10]}
    svm_model = GridSearchCV(svm_model, parameters)
    svm_model.fit(train_data, train_labels)
    
    predictions = svm_model.predict(test_data)
    accuracy = accuracy_score(test_labels, predictions)
    print(f'Accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100svmRadial.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.8666666666666667
# 2
# Accuracy: 0.9
# 3
# Accuracy: 0.9333333333333333
# 4
# Accuracy: 0.8666666666666667
# 5
# Accuracy: 0.8
# 6
# Accuracy: 0.7666666666666667
# 7
# Accuracy: 0.8333333333333334
# 8
# Accuracy: 0.8666666666666667
# 9
# Accuracy: 0.8666666666666667
# 10
# Accuracy: 0.9333333333333333
# 11
# Accuracy: 0.7
# 12
# Accuracy: 0.9
# 13
# Accuracy: 0.8
# 14
# Accuracy: 0.7333333333333333
# 15
# Accuracy: 0.9
# 16
# Accuracy: 0.8
# 17
# Accuracy: 0.9
# 18
# Accuracy: 0.8333333333333334
# 19
# Accuracy: 0.7666666666666667
# 20
# Accuracy: 0.7666666666666667
# 21
# Accuracy: 0.7666666666666667
# 22
# Accuracy: 0.8
# 23
# Accuracy: 0.8
# 24
# Accuracy: 0.8666666666666667
# 25
# Accuracy: 0.8
# 26
# Accuracy: 0.8333333333333334
# 27
# Accuracy: 0.8333333333333334
# 28
# Accuracy: 0.7333333333333333
# 29
# Accuracy: 0.8666666666666667
# 30
# Accuracy: 0.8333333333333334
# 31
# Accuracy: 0.8
# 32
# Accuracy: 0.9333333333333333
# 33
# Accuracy: 0.8666666666666667
# 34
# Accuracy: 0.9
# 35
# Accuracy: 0.8333333333333334
# 36
# Accuracy: 0.7
# 37
# Accuracy: 0.9
# 38
# Accuracy: 0.7333333333333333
# 39
# Accuracy: 0.8666666666666667
# 40
# Accuracy: 0.7333333333333333
# 41
# Accuracy: 0.8666666666666667
# 42
# Accuracy: 0.9333333333333333
# 43
# Accuracy: 0.9
# 44
# Accuracy: 0.8333333333333334
# 45
# Accuracy: 0.8
# 46
# Accuracy: 0.8
# 47
# Accuracy: 0.8333333333333334
# 48
# Accuracy: 0.8333333333333334
# 49
# Accuracy: 0.8
# 50
# Accuracy: 0.8666666666666667
# 51
# Accuracy: 0.8666666666666667
# 52
# Accuracy: 0.8
# 53
# Accuracy: 0.9666666666666667
# 54
# Accuracy: 0.8666666666666667
# 55
# Accuracy: 0.9
# 56
# Accuracy: 0.8333333333333334
# 57
# Accuracy: 0.8333333333333334
# 58
# Accuracy: 0.7333333333333333
# 59
# Accuracy: 0.9
# 60
# Accuracy: 0.8666666666666667
# 61
# Accuracy: 0.8333333333333334
# 62
# Accuracy: 0.8
# 63
# Accuracy: 0.9
# 64
# Accuracy: 0.8666666666666667
# 65
# Accuracy: 0.9
# 66
# Accuracy: 0.8666666666666667
# 67
# Accuracy: 0.7666666666666667
# 68
# Accuracy: 0.9333333333333333
# 69
# Accuracy: 0.9
# 70
# Accuracy: 0.9
# 71
# Accuracy: 0.8
# 72
# Accuracy: 0.9
# 73
# Accuracy: 0.8333333333333334
# 74
# Accuracy: 0.8333333333333334
# 75
# Accuracy: 0.8
# 76
# Accuracy: 0.8333333333333334
# 77
# Accuracy: 0.8333333333333334
# 78
# Accuracy: 0.7666666666666667
# 79
# Accuracy: 0.8
# 80
# Accuracy: 0.8
# 81
# Accuracy: 0.7666666666666667
# 82
# Accuracy: 0.7666666666666667
# 83
# Accuracy: 0.7333333333333333
# 84
# Accuracy: 0.8
# 85
# Accuracy: 0.8666666666666667
# 86
# Accuracy: 0.8
# 87
# Accuracy: 0.8333333333333334
# 88
# Accuracy: 0.8
# 89
# Accuracy: 0.8333333333333334
# 90
# Accuracy: 0.9
# 91
# Accuracy: 0.8666666666666667
# 92
# Accuracy: 0.6666666666666666
# 93
# Accuracy: 0.8
# 94
# Accuracy: 0.7666666666666667
# 95
# Accuracy: 0.8666666666666667
# 96
# Accuracy: 1.0
# 97
# Accuracy: 0.7666666666666667
# 98
# Accuracy: 0.9333333333333333
# 99
# Accuracy: 0.9333333333333333
# 100
# Accuracy: 0.8666666666666667

# %% [markdown]
# ### Individual Features

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                        CpG_Data['APPRDX'], test_size=0.2)
        
        svm_model = SVC(kernel='rbf')
        parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100], 'gamma': [0.01, 0.1, 1, 10]}
        svm_model = GridSearchCV(svm_model, parameters)
        svm_model.fit(train_data, train_labels)

        predictions = svm_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_svmR.csv", output, delimiter=",")
        joblib.dump(svm_model, f"{col}_svmR_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.7666666666666667
# Accuracy for column cg04983473: 0.6666666666666666
# Accuracy for column cg25943702: 0.8333333333333334
# Accuracy for column cg01620849: 0.7333333333333333
# Accuracy for column cg22210403: 0.7
# Accuracy for column cg21241862: 0.8333333333333334
# Accuracy for column cg19030090: 0.6333333333333333
# Accuracy for column cg02232418: 0.7666666666666667
# Accuracy for column cg18757169: 0.8333333333333334
# Accuracy for column cg02992048: 0.7
# Accuracy for column cg22810281: 0.6333333333333333
# Accuracy for column cg17780657: 0.6333333333333333
# Accuracy for column cg20230179: 0.7666666666666667
# Accuracy for column cg24573261: 0.7333333333333333
# Accuracy for column cg08497332: 0.7666666666666667
# Accuracy for column cg15442746: 0.7666666666666667
# Accuracy for column cg23641264: 0.7
_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1), 
                                                                        CpG_Data['APPRDX'], test_size=0.2)
    
    svm_model = SVC(kernel='poly', degree=3)
    parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100], 'gamma': [0.01, 0.1, 1, 10]}
    svm_model = GridSearchCV(svm_model, parameters)
    svm_model.fit(train_data, train_labels)
    
    predictions = svm_model.predict(test_data)
    accuracy = accuracy_score(test_labels, predictions)
    print(f'Accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100svmPoly.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.8
# 2
# Accuracy: 0.9
# 3
# Accuracy: 0.8666666666666667
# 4
# Accuracy: 0.8333333333333334
# 5
# Accuracy: 0.7333333333333333
# 6
# Accuracy: 0.8666666666666667
# 7
# Accuracy: 0.8333333333333334
# 8
# Accuracy: 0.8666666666666667
# 9
# Accuracy: 0.8
# 10
# Accuracy: 0.8333333333333334
# 11
# Accuracy: 0.9
# 12
# Accuracy: 0.7666666666666667
# 13
# Accuracy: 0.9
# 14
# Accuracy: 0.8333333333333334
# 15
# Accuracy: 0.7333333333333333
# 16
# Accuracy: 0.8333333333333334
# 17
# Accuracy: 0.9333333333333333
# 18
# Accuracy: 0.8333333333333334
# 19
# Accuracy: 0.8666666666666667
# 20
# Accuracy: 0.8333333333333334
# 21
# Accuracy: 0.9
# 22
# Accuracy: 0.9333333333333333
# 23
# Accuracy: 0.8333333333333334
# 24
# Accuracy: 0.8333333333333334
# 25
# Accuracy: 0.9
# 26
# Accuracy: 0.8
# 27
# Accuracy: 0.9
# 28
# Accuracy: 0.8666666666666667
# 29
# Accuracy: 0.9
# 30
# Accuracy: 0.9
# 31
# Accuracy: 0.8333333333333334
# 32
# Accuracy: 0.9
# 33
# Accuracy: 0.8666666666666667
# 34
# Accuracy: 0.9
# 35
# Accuracy: 0.9
# 36
# Accuracy: 0.8666666666666667
# 37
# Accuracy: 0.8333333333333334
# 38
# Accuracy: 0.8666666666666667
# 39
# Accuracy: 0.8333333333333334
# 40
# Accuracy: 1.0
# 41
# Accuracy: 0.8333333333333334
# 42
# Accuracy: 0.8333333333333334
# 43
# Accuracy: 0.8
# 44
# Accuracy: 0.7666666666666667
# 45
# Accuracy: 0.9666666666666667
# 46
# Accuracy: 0.9333333333333333
# 47
# Accuracy: 0.9
# 48
# Accuracy: 0.8
# 49
# Accuracy: 0.9
# 50
# Accuracy: 0.9
# 51
# Accuracy: 0.8333333333333334
# 52
# Accuracy: 0.8666666666666667
# 53
# Accuracy: 0.8666666666666667
# 54
# Accuracy: 0.8666666666666667
# 55
# Accuracy: 0.8666666666666667
# 56
# Accuracy: 0.8666666666666667
# 57
# Accuracy: 0.9
# 58
# Accuracy: 0.8333333333333334
# 59
# Accuracy: 0.9
# 60
# Accuracy: 0.8
# 61
# Accuracy: 0.8333333333333334
# 62
# Accuracy: 0.8666666666666667
# 63
# Accuracy: 0.9333333333333333
# 64
# Accuracy: 0.9
# 65
# Accuracy: 0.7333333333333333
# 66
# Accuracy: 0.9333333333333333
# 67
# Accuracy: 0.7666666666666667
# 68
# Accuracy: 0.9333333333333333
# 69
# Accuracy: 0.8333333333333334
# 70
# Accuracy: 0.8666666666666667
# 71
# Accuracy: 0.8666666666666667
# 72
# Accuracy: 0.8333333333333334
# 73
# Accuracy: 0.8
# 74
# Accuracy: 0.8333333333333334
# 75
# Accuracy: 0.7333333333333333
# 76
# Accuracy: 0.9
# 77
# Accuracy: 0.8666666666666667
# 78
# Accuracy: 0.7333333333333333
# 79
# Accuracy: 0.7666666666666667
# 80
# Accuracy: 0.9
# 81
# Accuracy: 0.8333333333333334
# 82
# Accuracy: 0.8333333333333334
# 83
# Accuracy: 0.8666666666666667
# 84
# Accuracy: 0.8666666666666667
# 85
# Accuracy: 0.7666666666666667
# 86
# Accuracy: 0.8
# 87
# Accuracy: 0.8333333333333334
# 88
# Accuracy: 0.9333333333333333
# 89
# Accuracy: 0.9
# 90
# Accuracy: 0.8
# 91
# Accuracy: 0.8666666666666667
# 92
# Accuracy: 0.8
# 93
# Accuracy: 0.7666666666666667
# 94
# Accuracy: 0.9
# 95
# Accuracy: 0.9
# 96
# Accuracy: 0.8
# 97
# Accuracy: 0.8666666666666667
# 98
# Accuracy: 0.8333333333333334
# 99
# Accuracy: 0.8666666666666667
# 100
# Accuracy: 0.8666666666666667

# %% [markdown]
# for col in CpG_Data.columns:
#     if col != 'APPRDX':
#         output = []
#         train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]],
#                                         CpG_Data['APPRDX'], test_size=0.2)
#
#         svm_model = SVC(kernel='poly', degree=3)
#         parameters = {'C': [0.01, 0.1, 0.5, 1, 5, 10, 50, 100], 'gamma': [0.01, 0.1, 1, 10]}
#         svm_model = GridSearchCV(svm_model, parameters)
#         svm_model.fit(train_data, train_labels)
#
#         predictions = svm_model.predict(test_data)
#         accuracy = accuracy_score(test_labels, predictions)
#         print(f'Accuracy for column {col}: {accuracy}')
#         output.append(accuracy)
#
#         np.savetxt(f"{col}_svmP.csv", output, delimiter=",")
#         joblib.dump(svm_model, f"{col}_svmP_model.joblib")

# %% [markdown]
#     hinge: This is the default loss function for the linear SVM classifier, which maximizes the margin between the two classes. It is also known as the max-margin hinge loss, and is typically used for binary classification problems.
#
#     log_loss: This is the logistic regression loss function, also known as the cross-entropy loss. It is used to train linear classifiers that predict class probabilities. It is suitable for both binary and multi-class classification problems.
#
#     modified_huber: This is a smoothed version of the hinge loss that is less sensitive to outliers. It combines the best properties of the hinge and log loss functions and is useful for noisy data and datasets with mislabeled samples.
#
#     squared_hinge: This is a variant of the hinge loss that is squared. It is more sensitive to samples that are closer to the decision boundary and can be used to train non-linear classifiers.
#
#     perceptron: This is the perceptron algorithm, which is a linear binary classifier. It updates the weight vector in each iteration using only the misclassified samples.
#
#     squared_error: This is the mean squared error (MSE) loss function, which is used to train linear regression models. It minimizes the sum of the squared errors between the predicted and actual target values.
#
#     huber: This is a robust regression loss function that combines the best properties of MSE and absolute error loss functions. It is less sensitive to outliers than the MSE loss and is useful for datasets with noisy or corrupted samples.
#
#     epsilon_insensitive: This is the epsilon-insensitive loss function, which is used for support vector regression (SVR). It ignores errors that are within a certain distance epsilon from the actual target value.
#
#     squared_epsilon_insensitive: This is a squared version of the epsilon-insensitive loss function, which is also used for SVR. It is more sensitive to larger errors than the regular epsilon-insensitive loss.

# %% [markdown]
# # Boosting

# %% [markdown]
# ## Adaptive Boosting

# %%
output = []
for i in range(1, 101):
    print(f'Iteration {i}')
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    rf_model = RandomForestClassifier()
    ada_model = AdaBoostClassifier(base_estimator=rf_model)
    parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
    ada_model = GridSearchCV(ada_model, parameters)
    cv_scores = cross_val_score(ada_model, X, y, cv=10)
    mean_accuracy = np.mean(cv_scores)
    std_accuracy = np.std(cv_scores)
    print(f'Cross-validation accuracy: {mean_accuracy} +/- {std_accuracy}')
    output.append(mean_accuracy)

np.savetxt("All5_Top50sCpG_Female_100AdaBoost.csv", output, delimiter=",")
# Out:
# Iteration 1
# Cross-validation accuracy: 0.76 +/- 0.085374989832438
# Iteration 2
# Cross-validation accuracy: 0.7666666666666666 +/- 0.07453559924999302
# Iteration 3
# Cross-validation accuracy: 0.7866666666666667 +/- 0.10241527663824812
# Iteration 4
# Cross-validation accuracy: 0.7733333333333333 +/- 0.0952190457139047
# Iteration 5
# Cross-validation accuracy: 0.7933333333333332 +/- 0.1008849730028104
# Iteration 6
# Cross-validation accuracy: 0.7799999999999999 +/- 0.08969082698049144
# Iteration 7
# Cross-validation accuracy: 0.78 +/- 0.08969082698049143
# Iteration 8
# Cross-validation accuracy: 0.7733333333333333 +/- 0.0997775303139718
# Iteration 9
# Cross-validation accuracy: 0.7733333333333332 +/- 0.10413666234542208
# Iteration 10
# Cross-validation accuracy: 0.7466666666666667 +/- 0.09333333333333335
# Iteration 11
# Cross-validation accuracy: 0.7733333333333333 +/- 0.09521904571390469
# Iteration 12
# Cross-validation accuracy: 0.7666666666666666 +/- 0.10000000000000002
# Iteration 13
# Cross-validation accuracy: 0.7933333333333332 +/- 0.06289320754704406
# Iteration 14
# Cross-validation accuracy: 0.7733333333333332 +/- 0.10832051206181283
# Iteration 15
# Cross-validation accuracy: 0.78 +/- 0.07333333333333336
# Iteration 16
# Cross-validation accuracy: 0.76 +/- 0.08000000000000003
# Iteration 17
# Cross-validation accuracy: 0.7733333333333333 +/- 0.09521904571390469
# Iteration 18
# Cross-validation accuracy: 0.7666666666666667 +/- 0.09545214042184237
# Iteration 19
# Cross-validation accuracy: 0.78 +/- 0.10349449797506685
# Iteration 20
# Cross-validation accuracy: 0.78 +/- 0.08969082698049143
# Iteration 21
# Cross-validation accuracy: 0.7933333333333332 +/- 0.08137703743822472
# Iteration 22
_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1), 
                                                                        CpG_Data['APPRDX'], test_size=0.2)
    
    rf_model = RandomForestClassifier()
    ada_model = AdaBoostClassifier(base_estimator=rf_model)
    parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
    ada_model = GridSearchCV(ada_model, parameters)
    ada_model.fit(train_data, train_labels)
    
    predictions = ada_model.predict(test_data)
    accuracy = accuracy_score(test_labels, predictions)
    print(f'Accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100AdaBoost.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.9
# 2
# Accuracy: 0.6666666666666666
# 3
# Accuracy: 0.8
# 4
# Accuracy: 0.7333333333333333
# 5
# Accuracy: 0.9
# 6
# Accuracy: 0.8
# 7
# Accuracy: 0.8333333333333334
# 8
# Accuracy: 0.8
# 9
# Accuracy: 0.6333333333333333
# 10
# Accuracy: 0.7333333333333333
# 11
# Accuracy: 0.7666666666666667
# 12
# Accuracy: 0.8
# 13
# Accuracy: 0.7666666666666667
# 14
# Accuracy: 0.8333333333333334
# 15
# Accuracy: 0.8333333333333334
# 16
# Accuracy: 0.7333333333333333
# 17
# Accuracy: 0.8333333333333334
# 18
# Accuracy: 0.7
# 19
# Accuracy: 0.8
# 20
# Accuracy: 0.9
# 21
# Accuracy: 0.8666666666666667
# 22
# Accuracy: 0.8333333333333334
# 23
# Accuracy: 0.7666666666666667
# 24
# Accuracy: 0.8333333333333334
# 25
# Accuracy: 0.9333333333333333
# 26
# Accuracy: 0.9333333333333333
# 27
# Accuracy: 0.6666666666666666
# 28
# Accuracy: 0.8333333333333334
# 29
# Accuracy: 0.7666666666666667
# 30
# Accuracy: 0.8666666666666667
# 31
# Accuracy: 0.7666666666666667
# 32
# Accuracy: 0.6333333333333333
# 33
# Accuracy: 0.8
# 34
# Accuracy: 0.7666666666666667
# 35
# Accuracy: 0.8666666666666667
# 36
# Accuracy: 0.7333333333333333
# 37
# Accuracy: 0.6333333333333333
# 38
# Accuracy: 0.8666666666666667
# 39
# Accuracy: 0.8
# 40
# Accuracy: 0.7666666666666667
# 41
# Accuracy: 0.6333333333333333
# 42
# Accuracy: 0.7
# 43
# Accuracy: 0.7
# 44
# Accuracy: 0.6666666666666666
# 45
# Accuracy: 0.7
# 46
# Accuracy: 0.7666666666666667
# 47
# Accuracy: 0.9
# 48
# Accuracy: 0.8333333333333334
# 49
# Accuracy: 0.7666666666666667
# 50
# Accuracy: 0.7333333333333333
# 51
# Accuracy: 0.7666666666666667
# 52
# Accuracy: 0.9
# 53
# Accuracy: 0.5666666666666667
# 54
# Accuracy: 0.7666666666666667
# 55
# Accuracy: 0.7666666666666667
# 56
# Accuracy: 0.9
# 57
# Accuracy: 0.6333333333333333
# 58
# Accuracy: 0.8
# 59
# Accuracy: 0.7666666666666667
# 60
# Accuracy: 0.8
# 61
# Accuracy: 0.8333333333333334
# 62
# Accuracy: 0.7333333333333333
# 63
# Accuracy: 0.7
# 64
# Accuracy: 0.5666666666666667
# 65
# Accuracy: 0.8
# 66
# Accuracy: 0.8666666666666667
# 67
# Accuracy: 0.7666666666666667
# 68
# Accuracy: 0.7666666666666667
# 69
# Accuracy: 0.8
# 70
# Accuracy: 0.8666666666666667
# 71
# Accuracy: 0.7666666666666667
# 72
# Accuracy: 0.8
# 73
# Accuracy: 0.7
# 74
# Accuracy: 0.7666666666666667
# 75
# Accuracy: 0.8333333333333334
# 76
# Accuracy: 0.9333333333333333
# 77
# Accuracy: 0.6666666666666666
# 78
# Accuracy: 0.8
# 79
# Accuracy: 0.7666666666666667
# 80
# Accuracy: 0.7
# 81
# Accuracy: 0.9
# 82
# Accuracy: 0.8333333333333334
# 83
# Accuracy: 0.8
# 84
# Accuracy: 0.8666666666666667
# 85
# Accuracy: 0.7333333333333333
# 86
# Accuracy: 0.8
# 87
# Accuracy: 0.7666666666666667
# 88
# Accuracy: 0.6666666666666666
# 89
# Accuracy: 0.8
# 90
# Accuracy: 0.8
# 91
# Accuracy: 0.7333333333333333
# 92
# Accuracy: 0.8333333333333334
# 93
# Accuracy: 0.7666666666666667
# 94
# Accuracy: 0.7666666666666667
# 95
# Accuracy: 0.7333333333333333
# 96
# Accuracy: 0.7666666666666667
# 97
# Accuracy: 0.7666666666666667
# 98
# Accuracy: 0.8666666666666667
# 99
# Accuracy: 0.8
# 100
# Accuracy: 0.9333333333333333

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                                                            CpG_Data['APPRDX'], test_size=0.2)
        
        rf_model = RandomForestClassifier()
        ada_model = AdaBoostClassifier(base_estimator=rf_model)
        parameters = {'n_estimators': [300], 'learning_rate': [0.1]}
        ada_model = GridSearchCV(ada_model, parameters, n_jobs=-1)
        ada_model.fit(train_data, train_labels)

        predictions = ada_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_AdaBoost.csv", output, delimiter=",")
        joblib.dump(ada_model, f"{col}_AdaBoost_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.5333333333333333
# Accuracy for column cg04983473: 0.8
# Accuracy for column cg25943702: 0.5666666666666667
# Accuracy for column cg01620849: 0.6333333333333333
# Accuracy for column cg22210403: 0.5666666666666667
# Accuracy for column cg21241862: 0.6
# Accuracy for column cg19030090: 0.6333333333333333
# Accuracy for column cg02232418: 0.6666666666666666
# Accuracy for column cg18757169: 0.6
# Accuracy for column cg02992048: 0.7333333333333333
# Accuracy for column cg22810281: 0.5333333333333333
# Accuracy for column cg17780657: 0.6666666666666666
# Accuracy for column cg20230179: 0.6666666666666666
# Accuracy for column cg24573261: 0.8333333333333334
# Accuracy for column cg08497332: 0.6666666666666666
# Accuracy for column cg15442746: 0.6
_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], CpG_Data['APPRDX'], test_size=0.2)
#     rf_model = RandomForestClassifier()
#     ada_model = AdaBoostClassifier(base_estimator=rf_model)
#     parameters = {'n_estimators': [300], 'learning_rate': [0.1]}
#     ada_model = GridSearchCV(ada_model, parameters, n_jobs=-1)
#     ada_model.fit(train_data, train_labels)
#     predictions = ada_model.predict(test_data)
#     accuracy = accuracy_score(test_labels, predictions)
#     print(f'Accuracy for column {col}: {accuracy}')
#     output.append(accuracy)
#     np.savetxt(f"{col}_AdaBoost.csv", output, delimiter=",")
#     joblib.dump(ada_model, f"{col}_AdaBoost_model.joblib")
#
# Parallel(n_jobs=-1)(delayed(process_column)(col) for col in CpG_Data.columns if col != 'APPRDX')

# %% [markdown]
# ## Gradient Boosting

# %% [markdown]
# output = []
# for i in range(1, 101):
#     print(f'Iteration {i}')
#     X = CpG_Data.drop('APPRDX', axis=1)
#     y = CpG_Data['APPRDX']
#     gb_model = GradientBoostingClassifier()
#     parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10], 'max_depth': [3, 4, 5]}
#     gb_model = GridSearchCV(gb_model, parameters)
#     cv_scores = cross_val_score(gb_model, X, y, cv=10)
#     mean_accuracy = np.mean(cv_scores)
#     std_accuracy = np.std(cv_scores)
#     print(f'Cross-validation accuracy: {mean_accuracy} +/- {std_accuracy}')
#     output.append(mean_accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100GradientBoost.csv", output, delimiter=",")

# %% [markdown]
# output = []
# for i in range(1, 101):
#     print(i)
#     train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1),
#                                                                         CpG_Data['APPRDX'], test_size=0.2)
#
#     gb_model = GradientBoostingClassifier()
#     parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
#     gb_model = GridSearchCV(gb_model, parameters)
#     gb_model.fit(train_data, train_labels)
#
#     predictions = gb_model.predict(test_data)
#     accuracy = accuracy_score(test_labels, predictions)
#     print(f'Accuracy: {accuracy}')
#     output.append(accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100GradientBoosting.csv", output, delimiter=",")

# %% [markdown]
# for col in CpG_Data.columns:
#     if col != 'APPRDX':
#         output = []
#         train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]],
#                                                                 CpG_Data['APPRDX'], test_size=0.2)
#
#         rf_model = RandomForestClassifier()
#         gb_model = GradientBoostingClassifier(base_estimator=rf_model)
#         gb_model = GradientBoostingClassifier()
#         parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
#         gb_model = GridSearchCV(gb_model, parameters)
#         gb_model.fit(train_data, train_labels)
#
#         predictions = gb_model.predict(test_data)
#         accuracy = accuracy_score(test_labels, predictions)
#         print(f'Accuracy for column {col}: {accuracy}')
#         output.append(accuracy)
#
#         np.savetxt(f"{col}_GradBoost.csv", output, delimiter=",")
#         joblib.dump(gb_model, f"{col}_GradBoost_model.joblib")

# %% [markdown]
# ## Extra Gradient Boosting

# %% [markdown]
# CpG_Data['APPRDX'] = CpG_Data['APPRDX'].replace(['Patient'], 0)
# CpG_Data['APPRDX'] = CpG_Data['APPRDX'].replace(['Healthy'], 1)
# CpG_Data.head(2)

# %% [markdown]
# import xgboost as xgb
#
# output = []
# for i in range(1, 101):
#     print(f'Iteration {i}')
#     X = CpG_Data.drop('APPRDX', axis=1)
#     y = CpG_Data['APPRDX']
#     xgb_model = xgb.XGBClassifier()
#     parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10], 'max_depth': [3, 4, 5]}
#     xgb_model = GridSearchCV(xgb_model, parameters)
#     cv_scores = cross_val_score(xgb_model, X, y, cv=10)
#     mean_accuracy = np.mean(cv_scores)
#     std_accuracy = np.std(cv_scores)
#     print(f'Cross-validation accuracy: {mean_accuracy} +/- {std_accuracy}')
#     output.append(mean_accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100XGBClassifier.csv", output, delimiter=",")

# %% [markdown]
# output = []
# for i in range(1, 101):
#     print(i)
#     train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1),
#                                                                         CpG_Data['APPRDX'], test_size=0.2)
#
#     xgb_model = XGBClassifier()
#     parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
#     xgb_model = GridSearchCV(xgb_model, parameters)
#     xgb_model.fit(train_data, train_labels)
#
#     predictions = xgb_model.predict(test_data)
#     accuracy = accuracy_score(test_labels, predictions)
#     print(f'Accuracy: {accuracy}')
#     output.append(accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100XGBoost.csv", output, delimiter=",")

# %% [markdown]
# for col in CpG_Data.columns:
#     if col != 'APPRDX':
#         output = []
#         train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]],
#                                                                 CpG_Data['APPRDX'], test_size=0.2)
#
#         xgb_model = XGBClassifier()
#         parameters = {'n_estimators': [50, 100, 200, 300], 'learning_rate': [0.01, 0.1, 1, 10]}
#         xgb_model = GridSearchCV(xgb_model, parameters)
#         xgb_model.fit(train_data, train_labels)
#
#         predictions = xgb_model.predict(test_data)
#         accuracy = accuracy_score(test_labels, predictions)
#         print(f'Accuracy for column {col}: {accuracy}')
#         output.append(accuracy)
#
#         np.savetxt(f"{col}_XGBoost.csv", output, delimiter=",")
#         joblib.dump(xgb_model, f"{col}_XGBoost_model.joblib")

# %% [markdown]
# # LDA

# %%
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    lda_model = LinearDiscriminantAnalysis(solver='svd', n_components=None)
    lda_model.fit(X_train, y_train)
    
    cv_scores = cross_val_score(lda_model, X, y, cv=10)
    mean_cv_score = np.mean(cv_scores)
    print(f'Mean cross-validation accuracy: {mean_cv_score}')
    
    predictions = lda_model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Test accuracy: {accuracy}')
    output.append(accuracy)
    
np.savetxt("All5_Top50sCpG_Female_100LDA.csv", output, delimiter=",")
# Out:
# 1
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 2
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 3
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 4
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 5
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 6
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 7
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 8
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 9
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 10
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 11
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 12
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 13
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 14
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 15
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 16
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 17
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 18
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 19
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 20
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 21
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 22
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 23
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 24
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 25
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 26
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 27
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 28
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 29
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 30
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 31
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 32
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 33
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 34
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 35
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 36
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 37
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 38
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 39
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 40
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 41
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 42
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 43
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 44
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 45
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 46
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 47
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 48
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 49
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 50
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 51
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 52
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 53
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 54
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 55
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 56
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 57
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 58
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 59
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 60
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 61
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 62
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 63
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 64
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 65
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 66
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 67
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 68
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 69
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 70
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 71
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 72
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 73
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 74
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.6666666666666666
# 75
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 76
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 77
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 78
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 79
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 80
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 81
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 82
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 83
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 84
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 85
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.9
# 86
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 87
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7
# 88
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 89
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 90
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 91
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 92
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 93
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 94
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8666666666666667
# 95
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 96
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7666666666666667
# 97
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333
# 98
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8333333333333334
# 99
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.8
# 100
# Mean cross-validation accuracy: 0.8066666666666669
# Test accuracy: 0.7333333333333333

# %% [markdown]
#     solver: LDA has four solvers to choose from, namely svd, lsqr, eigen, and lsqr. The default solver is svd, which is a good choice for small datasets. If you have a larger dataset, you may want to try the lsqr or eigen solvers.
#     shrinkage: LDA can use shrinkage to improve the estimation of the covariance matrix of the data. Shrinkage can be particularly useful when the number of features is much larger than the number of training samples. The shrinkage parameter can be set to auto to automatically choose the shrinkage intensity, or a float value between 0 and 1 to specify a specific level of shrinkage.
#     n_components: LDA can also be used for dimensionality reduction, in which case you would set the n_components parameter to a value smaller than the original number of features. This can help to reduce overfitting and speed up training and prediction. However, for classification purposes, you would typically set n_components to None to retain all the features.
#
# Here's a brief explanation of the four solvers available in scikit-learn's LDA implementation:
#
#     svd: This is the default solver and is based on singular value decomposition (SVD). It is the most efficient solver for small to moderate-sized datasets, and it works well when the number of samples is much larger than the number of features.
#
#     lsqr: This solver is based on a conjugate gradient algorithm, and it is particularly effective for larger datasets. It works by iteratively solving the linear system Ax = b, where A is the input data, b is the target variable, and x is the projection matrix.
#
#     eigen: This solver computes the eigenvalues and eigenvectors of the covariance matrix of the input data. It is a good choice when the number of features is much smaller than the number of samples.
#
#     eigen-sparse: This is a variation of the eigen solver that is designed for sparse input data.

# %% [markdown]
# # QDA

# %%
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
    
    qda_model = QuadraticDiscriminantAnalysis()
    qda_model.fit(X_train, y_train)
    
    cv_scores = cross_val_score(qda_model, X, y, cv=10)
    mean_cv_score = np.mean(cv_scores)
    print(f'Mean cross-validation accuracy: {mean_cv_score}')
    
    predictions = qda_model.predict(X_test)
    accuracy = accuracy_score(y_test, predictions)
    print(f'Test accuracy: {accuracy}')
    output.append(accuracy)
    
np.savetxt("All5_Top50sCpG_Female_100QDA.csv", output, delimiter=",")
# Out:
# 1
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6666666666666666
# 2
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7666666666666667
# 3
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 4
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5333333333333333
# 5
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7
# 6
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 7
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 8
# Mean cross-validation accuracy: 0.62
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Test accuracy: 0.7333333333333333
# 9
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 10
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6666666666666666
# 11
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5
# 12
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5
# 13
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7666666666666667
# 14
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6666666666666666
# 15
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 16
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 17
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7
# 18
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7666666666666667
# 19
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 20
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6333333333333333
# 21
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7333333333333333
# 22
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6666666666666666
# 23
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6333333333333333
# 24
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6333333333333333
# 25
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 26
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 27
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5333333333333333
# 28
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# ...
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.43333333333333335
# 91
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 92
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7333333333333333
# 93
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 94
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5666666666666667
# 95
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.5333333333333333
# 96
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 97
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6
# 98
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.7
# 99
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.6333333333333333
# 100
# Mean cross-validation accuracy: 0.62
# Test accuracy: 0.8333333333333334
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\discriminant_analysis.py:878: UserWarning: Variables are collinear
#   warnings.warn("Variables are collinear")

# %% [markdown]
# # KNN

# %%
from sklearn.metrics import accuracy_score 

output = []
for i in range(1, 101):
    print(i)
    X = CpG_Data.drop('APPRDX', axis=1)
    y = CpG_Data['APPRDX']
    
    # Splitting the dataset into the Training set and Test set
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.20)
    
    # Feature Scaling
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    # Training the K-NN model on the Training set
    from sklearn.neighbors import KNeighborsClassifier
    classifier = KNeighborsClassifier(n_neighbors = 5, metric = 'minkowski', p = 2)
    classifier.fit(X_train, y_train)
    
    # Predicting the Test set results
    y_pred = classifier.predict(X_test)

    # Making the Confusion Matrix
    from sklearn.metrics import confusion_matrix, accuracy_score
    cm = confusion_matrix(y_test, y_pred)
    ac = accuracy_score(y_test, y_pred)
    print(cm)
    print(ac)
    output.append(ac)

np.savetxt("All5_Top50sCpG_Female_100KNN.csv", output, delimiter=",")
# Out:
# 1
# [[ 1  9]
#  [ 0 20]]
# 0.7
# 2
# [[ 2  8]
#  [ 0 20]]
# 0.7333333333333333
# 3
# [[ 2  8]
#  [ 0 20]]
# 0.7333333333333333
# 4
# [[ 0 10]
#  [ 0 20]]
# 0.6666666666666666
# 5
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 6
# [[ 1  5]
#  [ 0 24]]
# 0.8333333333333334
# 7
# [[ 2  4]
#  [ 0 24]]
# 0.8666666666666667
# 8
# [[ 0  4]
#  [ 0 26]]
# 0.8666666666666667
# 9
# [[ 1  2]
#  [ 0 27]]
# 0.9333333333333333
# 10
# [[ 0  6]
#  [ 0 24]]
# 0.8
# 11
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 12
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 13
# [[ 3  7]
#  [ 0 20]]
# 0.7666666666666667
# 14
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 15
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 16
# [[ 1  3]
#  [ 0 26]]
# 0.9
# 17
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 18
# [[ 1  9]
#  [ 0 20]]
# 0.7
# 19
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 20
# [[ 2  6]
#  [ 0 22]]
# 0.8
# 21
# [[ 0  7]
#  [ 1 22]]
# 0.7333333333333333
# 22
# [[ 1  8]
#  [ 1 20]]
# 0.7
# 23
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 24
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 25
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [[ 0  9]
#  [ 0 21]]
# 0.7
# 26
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 27
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 28
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# 29
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# 30
# [[ 1  3]
#  [ 0 26]]
# 0.9
# 31
# [[ 0 10]
#  [ 0 20]]
# 0.6666666666666666
# 32
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# 33
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 34
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 35
# [[ 0  9]
#  [ 0 21]]
# 0.7
# 36
# [[ 0 12]
#  [ 0 18]]
# 0.6
# 37
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 38
# [[ 0  7]
#  [ 0 23]]
# 0.7666666666666667
# 39
# [[ 1  9]
#  [ 0 20]]
# 0.7
# 40
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 41
# [[ 0  7]
#  [ 0 23]]
# 0.7666666666666667
# 42
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 43
# [[ 0  7]
#  [ 0 23]]
# 0.7666666666666667
# 44
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 45
# [[ 2  7]
#  [ 0 21]]
# 0.7666666666666667
# 46
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 47
# [[ 0  4]
#  [ 0 26]]
# 0.8666666666666667
# 48
# [[ 2  9]
#  [ 0 19]]
# 0.7
# 49
# [[ 0  6]
#  [ 0 24]]
# 0.8
# 50
# [[ 2  8]
#  [ 0 20]]
# 0.7333333333333333
# 51
# [[ 1  3]
#  [ 0 26]]
# 0.9
# 52
# [[ 3  3]
#  [ 0 24]]
# 0.9
# 53
# [[ 2  4]
#  [ 0 24]]
# 0.8666666666666667
# 54
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# 55
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 56
# [[ 0 10]
#  [ 0 20]]
# 0.6666666666666666
# 57
# [[ 0 11]
#  [ 0 19]]
# 0.6333333333333333
# 58
# [[ 1  5]
#  [ 0 24]]
# 0.8333333333333334
# 59
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 60
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 61
# [[ 0 10]
#  [ 0 20]]
# 0.6666666666666666
# 62
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 63
# [[ 0  6]
#  [ 0 24]]
# 0.8
# 64
# [[ 1  4]
#  [ 0 25]]
# 0.8666666666666667
# 65
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 66
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 67
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 68
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 69
# [[ 1  9]
#  [ 0 20]]
# 0.7
# 70
# [[ 0  6]
#  [ 0 24]]
# 0.8
# 71
# [[ 0  6]
#  [ 0 24]]
# 0.8
# 72
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 73
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 74
# [[ 2  5]
#  [ 0 23]]
# 0.8333333333333334
# 75
# [[ 0  4]
#  [ 0 26]]
# 0.8666666666666667
# 76
# [[ 0  9]
#  [ 0 21]]
# 0.7
# 77
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 78
# [[ 2  6]
#  [ 0 22]]
# 0.8
# 79
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 80
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 81
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 82
# [[ 0 11]
#  [ 0 19]]
# 0.6333333333333333
# 83
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 84
# [[ 0  9]
#  [ 0 21]]
# 0.7
# 85
# [[ 0 10]
#  [ 0 20]]
# 0.6666666666666666
# 86
# [[ 1  6]
#  [ 0 23]]
# 0.8
# 87
# [[ 1  5]
#  [ 0 24]]
# 0.8333333333333334
# 88
# [[ 0  9]
#  [ 0 21]]
# 0.7
# 89
# [[ 2  7]
#  [ 0 21]]
# 0.7666666666666667
# 90
# [[ 1  5]
#  [ 0 24]]
# 0.8333333333333334
# 91
# [[ 0  5]
#  [ 0 25]]
# 0.8333333333333334
# 92
# [[ 1  7]
#  [ 0 22]]
# 0.7666666666666667
# 93
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# 94
# [[ 2  4]
#  [ 0 24]]
# 0.8666666666666667
# 95
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 96
# [[ 2  7]
#  [ 0 21]]
# 0.7666666666666667
# 97
# [[ 0  8]
#  [ 0 22]]
# 0.7333333333333333
# 98
# [[ 1  5]
#  [ 0 24]]
# 0.8333333333333334
# 99
# [[ 1  8]
#  [ 0 21]]
# 0.7333333333333333
# 100
# [[ 1 10]
#  [ 0 19]]
# 0.6666666666666666
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# #scipy.stats.mode(a, axis=0, nan_policy='propagate', keepdims=None)
# output = []
# for i in range(1, 101):
#     print(i)
#     train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1),
#                                                                         CpG_Data['APPRDX'], test_size=0.2)
#
#     knn_model = KNeighborsClassifier()
#     parameters = {'n_neighbors': [5, 10, 15, 20]}
#     knn_model = GridSearchCV(knn_model, parameters)
#     knn_model.fit(train_data, train_labels)
#
#     predictions = knn_model.predict(test_data)
#     accuracy = accuracy_score(test_labels, predictions)
#     print(f'Accuracy: {accuracy}')
#     output.append(accuracy)
#
# np.savetxt("All5_Top50sCpG_Female_100KNN.csv", output, delimiter=",")

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                                                CpG_Data['APPRDX'], test_size=0.2)
        
        knn_model = KNeighborsClassifier()
        parameters = {'n_neighbors': [5, 10, 15, 20]}
        knn_model = GridSearchCV(knn_model, parameters)
        knn_model.fit(train_data, train_labels)
        
        predictions = knn_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_KNN.csv", output, delimiter=",")
        joblib.dump(knn_model, f"{col}_KNN_model.joblib")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Accuracy for column cg11668199: 0.7666666666666667
# Accuracy for column cg04983473: 0.6666666666666666
# Accuracy for column cg25943702: 0.6666666666666666
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# ...
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Accuracy for column cg13520090: 0.9
# Accuracy for column cg05538980: 0.6666666666666666
# Accuracy for column cg18580385: 0.7666666666666667
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)

# %% [markdown]
# # Neural Network

# %%
output = []
for i in range(1, 101):
    print(i)
    train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data.drop('APPRDX', axis=1), 
                                                                        CpG_Data['APPRDX'], test_size=0.2)
    
    mlp_model = MLPClassifier()
    parameters = {'hidden_layer_sizes': [(20,10,5), (12,8)], 
                  'alpha': [0.0001, 0.001, 0.01, 0.1], 
                  'max_iter': [5000], 
                  'activation': ['relu', 'logistic']}
    mlp_model = GridSearchCV(mlp_model, parameters)
    mlp_model.fit(train_data, train_labels)
    
    predictions = mlp_model.predict(test_data)
    accuracy = accuracy_score(test_labels, predictions)
    print(f'Accuracy: {accuracy}')
    output.append(accuracy)

np.savetxt("All5_Top50sCpG_Female_100MLPNeuralNet.csv", output, delimiter=",")
# Out:
# 1
# Accuracy: 0.8333333333333334
# 2
# Accuracy: 0.9
# 3
# Accuracy: 0.7666666666666667
# 4
# Accuracy: 0.7333333333333333
# 5
# Accuracy: 0.7666666666666667
# 6
# Accuracy: 0.9
# 7
# Accuracy: 0.8333333333333334
# 8
# Accuracy: 0.8
# 9
# Accuracy: 0.6
# 10
# Accuracy: 0.6333333333333333
# 11
# Accuracy: 0.7
# 12
# Accuracy: 0.7333333333333333
# 13
# Accuracy: 0.9
# 14
# Accuracy: 0.6333333333333333
# 15
# Accuracy: 0.7333333333333333
# 16
# Accuracy: 0.7
# 17
# Accuracy: 0.8666666666666667
# 18
# Accuracy: 0.7
# 19
# Accuracy: 0.7333333333333333
# 20
# Accuracy: 0.7
# 21
# Accuracy: 0.9
# 22
# Accuracy: 0.7666666666666667
# 23
# Accuracy: 0.7666666666666667
# 24
# Accuracy: 0.8
# 25
# Accuracy: 0.8333333333333334
# 26
# Accuracy: 0.8333333333333334
# 27
# Accuracy: 0.6666666666666666
# 28
# Accuracy: 0.7666666666666667
# 29
# Accuracy: 0.8
# 30
# Accuracy: 0.6333333333333333
# 31
# Accuracy: 0.7333333333333333
# 32
# Accuracy: 0.9333333333333333
# 33
# Accuracy: 0.7
# 34
# Accuracy: 0.8666666666666667
# 35
# Accuracy: 0.7333333333333333
# 36
# Accuracy: 0.8
# 37
# Accuracy: 0.7333333333333333
# 38
# Accuracy: 0.6333333333333333
# 39
# Accuracy: 0.8333333333333334
# 40
# Accuracy: 0.7
# 41
# Accuracy: 0.8
# 42
# Accuracy: 0.9
# 43
# Accuracy: 0.8
# 44
# Accuracy: 0.9333333333333333
# 45
# Accuracy: 0.8333333333333334
# 46
# Accuracy: 0.9
# 47
# Accuracy: 0.8666666666666667
# 48
# Accuracy: 0.7
# 49
# Accuracy: 0.8333333333333334
# 50
# Accuracy: 0.8666666666666667
# 51
# Accuracy: 0.9333333333333333
# 52
# Accuracy: 0.8666666666666667
# 53
# Accuracy: 0.8333333333333334
# 54
# Accuracy: 0.7666666666666667
# 55
# Accuracy: 0.7333333333333333
# 56
# Accuracy: 0.7666666666666667
# 57
# Accuracy: 0.8666666666666667
# 58
# Accuracy: 0.8333333333333334
# 59
# Accuracy: 0.7333333333333333
# 60
# Accuracy: 0.6666666666666666
# 61
# Accuracy: 0.8333333333333334
# 62
# Accuracy: 0.7
# 63
# Accuracy: 0.8666666666666667
# 64
# Accuracy: 0.8666666666666667
# 65
# Accuracy: 0.8
# 66
# Accuracy: 0.8
# 67
# Accuracy: 0.6333333333333333
# 68
# Accuracy: 0.7333333333333333
# 69
# Accuracy: 0.6
# 70
# Accuracy: 0.7
# 71
# Accuracy: 0.8333333333333334
# 72
# Accuracy: 0.7666666666666667
# 73
# Accuracy: 0.9
# 74
# Accuracy: 0.7
# 75
# Accuracy: 0.6666666666666666
# 76
# Accuracy: 0.8
# 77
# Accuracy: 0.9
# 78
# Accuracy: 0.8
# 79
# Accuracy: 0.7666666666666667
# 80
# Accuracy: 0.6333333333333333
# 81
# Accuracy: 0.8
# 82
# Accuracy: 0.9
# 83
# Accuracy: 0.8333333333333334
# 84
# Accuracy: 0.6666666666666666
# 85
# Accuracy: 0.9
# 86
# Accuracy: 0.8666666666666667
# 87
# Accuracy: 0.9
# 88
# Accuracy: 0.8
# 89
# Accuracy: 0.7666666666666667
# 90
# Accuracy: 0.8
# 91
# Accuracy: 0.8333333333333334
# 92
# Accuracy: 0.8
# 93
# Accuracy: 0.7666666666666667
# 94
# Accuracy: 0.7333333333333333
# 95
# Accuracy: 0.9
# 96
# Accuracy: 0.9333333333333333
# 97
# Accuracy: 0.8333333333333334
# 98
# Accuracy: 0.9
# 99
# Accuracy: 0.8
# 100
# Accuracy: 0.7333333333333333

# %%
for col in CpG_Data.columns:
    if col != 'APPRDX':
        output = []
        train_data, test_data, train_labels, test_labels = train_test_split(CpG_Data[[col]], 
                                                                CpG_Data['APPRDX'], test_size=0.2)
        
        mlp_model = MLPClassifier()
        parameters = {'hidden_layer_sizes': [(10,), (5,), (10,50), (10,6,2)], 
                  'alpha': [0.0001, 0.001, 0.01, 0.1], 
                  'max_iter': [2000], 
                  'activation': ['relu', 'logistic']}
        mlp_model = GridSearchCV(mlp_model, parameters)
        mlp_model.fit(train_data, train_labels)
        
        predictions = mlp_model.predict(test_data)
        accuracy = accuracy_score(test_labels, predictions)
        print(f'Accuracy for column {col}: {accuracy}')
        output.append(accuracy)

        np.savetxt(f"{col}_MLPNN.csv", output, delimiter=",")
        joblib.dump(mlp_model, f"{col}_MLPNN_model.joblib")
# Out:
# Accuracy for column cg11668199: 0.7
# Accuracy for column cg04983473: 0.8
# Accuracy for column cg25943702: 0.8
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neural_network\_multilayer_perceptron.py:692: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (2000) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy for column c

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Define the base models
base_models = [('rf', RandomForestClassifier(n_estimators=100, random_state=1)),
               ('ada', AdaBoostClassifier(n_estimators=100, random_state=1)),
               ('gb', GradientBoostingClassifier(n_estimators=100, random_state=1)),
               ('svc', SVC(probability=True, random_state=1)),
               ('knn', KNeighborsClassifier(n_neighbors=5))]

# Define the voting ensemble model
voting_model = VotingClassifier(estimators=base_models)

# Define the stacking ensemble model
stacking_model = StackingClassifier(estimators=base_models, final_estimator=LogisticRegression())

# Train and evaluate the voting ensemble model
voting_model.fit(X_train, y_train)
voting_predictions = voting_model.predict(X_test)
voting_accuracy = accuracy_score(y_test, voting_predictions)
print(f'Voting ensemble accuracy: {voting_accuracy:.4f}')

# Train and evaluate the stacking ensemble model
stacking_model.fit(X_train, y_train)
stacking_predictions = stacking_model.predict(X_test)
stacking_accuracy = accuracy_score(y_test, stacking_predictions)
print(f'Stacking ensemble accuracy: {stacking_accuracy:.4f}')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\neighbors\_classification.py:228: FutureWarning: Unlike other reduction functions (e.g. `skew`, `kurtosis`), the default behavior of `mode` typically preserves the axis it acts along. In SciPy 1.11.0, this behavior will change: the default value of `keepdims` will become False, the `axis` over which the statistic is taken will be eliminated, and the value None will no longer be accepted. Set `keepdims` to True or False to avoid this warning.
#   mode, _ = stats.mode(_y[neigh_ind, k], axis=1)
# Voting ensemble accuracy: 0.8333
# Stacking ensemble accuracy: 0.8333

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, StackingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.metrics import accuracy_score, confusion_matrix

# Load the dataset and split into training and testing sets
X, y = CpG_Data.drop('APPRDX', axis=1), CpG_Data['APPRDX']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# Define the base models
base_models = [
    ('rf', RandomForestClassifier(n_estimators=100, random_state=1)),
    ('ada', AdaBoostClassifier(n_estimators=100, random_state=1)),
    ('svc', SVC(probability=True, random_state=1))
]

# Define the stacking ensemble model
stacking_model = StackingClassifier(
    estimators=base_models, final_estimator=LogisticRegression(max_iter=1000, random_state=1)
)

# Train and evaluate the stacking ensemble model using cross-validation
scaler = StandardScaler()  # Normalize the features
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

stacking_scores = cross_val_score(stacking_model, X_train_scaled, y_train, cv=5)
stacking_model.fit(X_train_scaled, y_train)

stacking_accuracy = accuracy_score(y_test, stacking_model.predict(X_test_scaled))

# Calculate the confusion matrix
conf_matrix = confusion_matrix(y_test, stacking_model.predict(X_test_scaled))


print(f'Stacking ensemble cross-validation scores: {stacking_scores}')
print(f'Mean Stacking ensemble CV score: {stacking_scores.mean():.4f}')
print(f'Stacking ensemble test accuracy: {stacking_accuracy:.4f}')


# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Stacking ensemble cross-validation scores: [0.875      0.83333333 0.83333333 0.83333333 0.83333333]
# Mean Stacking ensemble CV score: 0.8417
# Stacking ensemble test accuracy: 0.7667
# Confusion Matrix:
# [[ 4  1]
#  [ 6 19]]

# %% [markdown]
# Voting and stacking are two popular ensemble learning techniques in machine learning. They are used to combine the predictions of multiple base models to improve the accuracy and generalization of the final model.
#
# Voting: In a voting ensemble, multiple base models are trained on the same training data and their predictions are combined using majority voting. That is, the final prediction is determined by the most frequently predicted class across all of the base models. Voting can be done either by hard voting or soft voting. In hard voting, the class that gets the most votes across all models is the predicted class, while in soft voting, the probabilities of all models are averaged to determine the final prediction. Voting is a simple and effective ensemble technique, but it works best when the base models have low correlation with each other.
#
# Stacking: In a stacking ensemble, multiple base models are trained on the same training data and their predictions are used as input to a meta-model, which makes the final prediction. The meta-model is trained on the output of the base models, rather than the original input features. The idea behind stacking is to capture the strengths and weaknesses of the base models and learn how to best combine them. Stacking can be done using different meta-models, such as linear regression, logistic regression, or neural networks. The choice of meta-model depends on the problem domain and the nature of the base models. Stacking is more complex than voting, but it can lead to better performance if done correctly.
#
# Overall, both voting and stacking are useful ensemble techniques that can improve the performance of machine learning models. They are particularly useful when the base models have complementary strengths and weaknesses, and when there is a risk of overfitting to the training data.
