# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
from scipy.stats import pearsonr
from sklearn.metrics import pairwise_distances
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics.pairwise import cosine_similarity
# https://www.kaggle.com/code/fuzzywizard/rec-sys-collaborative-filtering-dl-techniques

# %%
# %cd Z:\PPMI_Data\Excels\CollaborativeFiltering
df = pd.read_csv('Feats45_unCategAge_APPRDX.csv')
df.shape
df.head(2)
# Out:
# Z:\PPMI_Data\Excels\CollaborativeFiltering
#    PATNO  Patient_ID  APPRDX        Age  Anxiety  Apathy  Benton  Clock  \
# 0   3002           1       1  67.578082        1       0   12.16      7
# 1   3010           2       1  46.965716        1       1    7.76      6
#
#    Cognition  COGSTATE  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0          1         1  ...        57         1           0     45     59
# 1          1         1  ...        36         1           3     40     39
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0          47.5             110             204     17      1
# 1          52.0              27              52      9      0
#
# [2 rows x 49 columns]

# %%
# Removing a column
df1 = df.drop(['PATNO','APPRDX'], axis = 1)
df1.head(2)
# Out:
#    Patient_ID        Age  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  \
# 0           1  67.578082        1       0   12.16      7          1         1
# 1           2  46.965716        1       1    7.76      6          1         1
#
#    Constipate  Depress  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0           1        1  ...        57         1           0     45     59
# 1           0        0  ...        36         1           3     40     39
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0          47.5             110             204     17      1
# 1          52.0              27              52      9      0
#
# [2 rows x 47 columns]

# %%
df2 = pd.read_csv('NonMotor_Empty.csv')
df2.shape
df2.head(2)
# Out:
#    Patient_ID  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  \
# 0         999      NaN     NaN     NaN    NaN        NaN       NaN
#
#    Constipate  Depress  DopaDefic  ...  Semantic  SleepDay  SleepNight  STAIA  \
# 0         NaN      NaN        NaN  ...       NaN       NaN         NaN    NaN
#
#    STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0    NaN           NaN             NaN             NaN    NaN    NaN
#
# [1 rows x 46 columns]

# %%
# Removing a column
df3 = df2.drop('Patient_ID', axis = 1)
df3.head(2)
# Out:
#    Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  Constipate  Depress  \
# 0      NaN     NaN     NaN    NaN        NaN       NaN         NaN      NaN
#
#    DopaDefic  Education  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0        NaN        NaN  ...       NaN       NaN         NaN    NaN    NaN
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0           NaN             NaN             NaN    NaN    NaN
#
# [1 rows x 45 columns]

# %%
# Ask the user for the updated value of age
new_age = int(input("What is the user's age (in years): "))

# Update the value of age in the dataframe
df3.at[0, 'Age'] = new_age

# Drop the 46th column from the original DataFrame
col_age = df3.pop('Age')

# Insert the column at the 5th position
df3.insert(0, "Age", col_age)
df3.head(2)
# Out:
# What is the user's age (in years): 44
#     Age  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  Constipate  \
# 0  44.0      NaN     NaN     NaN    NaN        NaN       NaN         NaN
#
#    Depress  DopaDefic  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0      NaN        NaN  ...       NaN       NaN         NaN    NaN    NaN
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0           NaN             NaN             NaN    NaN    NaN
#
# [1 rows x 46 columns]

# %%
#Below will take at least 3 features

# %%
def update_values(df3):
    # Input from the user for number of columns
    num_columns = int(input("Enter the number of columns you want to update (minimum 3, maximum 45): "))
    
    while num_columns < 3 or num_columns > 45:
        print("Invalid number of columns. Please enter a number between 3 and 45.")
        num_columns = int(input("Enter the number of columns you want to update (minimum 3, maximum 45): "))
    
    columns = []
    values = []
     
     # Loop to get input from the user for each column
    for i in range(num_columns):
        column = input("Enter the name of the Feature %d: " % (i + 1))
        value = input("Enter the score of the Feature %d: " % (i + 1))
        
        columns.append(column)
        values.append(int(value))
    
    # Update the values in the dataframe
    for i in range(num_columns):
        df3.loc[df3[columns[i]] != values[i], columns[i]] = values[i]
    
    return df3

# Call the function
df3 = update_values(df3)

# Print the updated dataframe
df3.head()
# Out:
# Enter the number of columns you want to update (minimum 3, maximum 45): 3
# Enter the name of the Feature 1: Apathy
# Enter the score of the Feature 1: 2
# Enter the name of the Feature 2: Clock
# Enter the score of the Feature 2: 6
# Enter the name of the Feature 3: UPSIT
# Enter the score of the Feature 3: 35
#     Age  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  Constipate  \
# 0  44.0      NaN     2.0     NaN    6.0        NaN       NaN         NaN
#
#    Depress  DopaDefic  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0      NaN        NaN  ...       NaN       NaN         NaN    NaN    NaN
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0           NaN             NaN             NaN   35.0    NaN
#
# [1 rows x 46 columns]

# %%
# Adding back the column (as the first column)
df3.insert (0, 'Patient_ID', df2['Patient_ID'])
df3.head()
# Out:
#    Patient_ID   Age  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  \
# 0         999  44.0      NaN     2.0     NaN    6.0        NaN       NaN
#
#    Constipate  Depress  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0         NaN      NaN  ...       NaN       NaN         NaN    NaN    NaN
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0           NaN             NaN             NaN   35.0    NaN
#
# [1 rows x 47 columns]

# %%
# merging two dataframes [original and our input dataframes]
merged_df = pd.concat ([df1, df3], axis = 0)
merged_df.reset_index(inplace = True)
merged_df.tail()
# Out:
#      index  Patient_ID        Age  Anxiety  Apathy  Benton  Clock  Cognition  \
# 246    246         248  57.447728      0.0     0.0   14.77    6.0        0.0
# 247    247         249  58.260371      0.0     0.0   14.18    6.0        0.0
# 248    248         250  66.383562      0.0     0.0   11.06    7.0        0.0
# 249    249         251  68.073973      0.0     0.0   11.06    7.0        0.0
# 250      0         999  44.000000      NaN     2.0     NaN    6.0        NaN
#
#      COGSTATE  Constipate  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 246       1.0         3.0  ...      47.0       0.0         0.0   46.0   44.0
# 247       1.0         0.0  ...      58.0       1.0         3.0   47.0   40.0
# 248       1.0         0.0  ...      49.0       2.0         1.0   45.0   46.0
# 249       1.0         0.0  ...      57.0       0.0         3.0   44.0   45.0
# 250       NaN         NaN  ...       NaN       NaN         NaN    NaN    NaN
#
#      Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 246     56.250000            27.0            75.0   36.0    0.0
# 247     58.750000            28.0            48.0   38.0    1.0
# 248     45.830002            36.0           106.0   32.0    1.0
# 249     50.000000            30.0            80.0   38.0    0.0
# 250           NaN             NaN             NaN   35.0    NaN
#
# [5 rows x 48 columns]

# %%
# dropping a few columns
merged_df1 = merged_df.drop(['index','Patient_ID'], axis = 1)
merged_df1.head(2)
# Out:
#          Age  Anxiety  Apathy  Benton  Clock  Cognition  COGSTATE  Constipate  \
# 0  67.578082      1.0     0.0   12.16    7.0        1.0       1.0         1.0
# 1  46.965716      1.0     1.0    7.76    6.0        1.0       1.0         0.0
#
#    Depress  DopaDefic  ...  Semantic  SleepDay  SleepNight  STAIA  STAIS  \
# 0      1.0        0.0  ...      57.0       1.0         0.0   45.0   59.0
# 1      0.0        0.0  ...      36.0       1.0         3.0   40.0   39.0
#
#    Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0          47.5           110.0           204.0   17.0    1.0
# 1          52.0            27.0            52.0    9.0    0.0
#
# [2 rows x 46 columns]

# %%
# scaling values of every column from 1 to 5 [column wise]
scaler = MinMaxScaler (feature_range = (1,5))
df_scaled = scaler.fit_transform(merged_df1)
df_scaled = pd.DataFrame (df_scaled, columns = merged_df1.columns)
df_scaled.head(2)
# Out:
#         Age   Anxiety  Apathy    Benton     Clock  Cognition  COGSTATE  \
# 0  3.786116  2.333333     1.0  3.503546  5.000000        3.0       1.0
# 1  2.232411  2.333333     3.0  1.943262  4.333333        3.0       1.0
#
#    Constipate  Depress  DopaDefic  ...  Semantic  SleepDay  SleepNight  \
# 0    2.333333      2.0        1.0  ...  3.285714       3.0         1.0
# 1    1.000000      1.0        1.0  ...  1.785714       3.0         4.0
#
#       STAIA  STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B     UPSIT  \
# 0  3.434783    5.0      2.833333        3.832117        3.686131  2.333333
# 1  2.565217    3.0      3.133333        1.408759        1.467153  1.363636
#
#    Urine
# 0    2.0
# 1    1.0
#
# [2 rows x 46 columns]

# %%
# adding the column [as the first column]
df_scaled.insert (0, 'Patient_ID', merged_df['Patient_ID'], True)
df_scaled.head(3)
# Out:
#    Patient_ID       Age   Anxiety  Apathy    Benton     Clock  Cognition  \
# 0           1  3.786116  2.333333     1.0  3.503546  5.000000        3.0
# 1           2  2.232411  2.333333     3.0  1.943262  4.333333        3.0
# 2           3  4.267435  1.000000     1.0  3.975177  5.000000        3.0
#
#    COGSTATE  Constipate  Depress  ...  Semantic  SleepDay  SleepNight  \
# 0       1.0    2.333333      2.0  ...  3.285714       3.0         1.0
# 1       1.0    1.000000      1.0  ...  1.785714       3.0         4.0
# 2       5.0    1.000000      1.0  ...  2.428571       3.0         3.0
#
#       STAIA  STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B     UPSIT  \
# 0  3.434783    5.0      2.833333        3.832117        3.686131  2.333333
# 1  2.565217    3.0      3.133333        1.408759        1.467153  1.363636
# 2  2.913043    3.3      2.555333        3.248175        4.386861  3.424242
#
#    Urine
# 0    2.0
# 1    1.0
# 2    1.0
#
# [3 rows x 47 columns]

# %%
df_scaled.tail(3)
# Out:
#      Patient_ID       Age  Anxiety  Apathy    Benton     Clock  Cognition  \
# 248         250  3.696076      1.0     1.0  3.113475  5.000000        1.0
# 249         251  3.823494      1.0     1.0  3.113475  5.000000        1.0
# 250         999  2.008863      NaN     5.0       NaN  4.333333        NaN
#
#      COGSTATE  Constipate  Depress  ...  Semantic  SleepDay  SleepNight  \
# 248       1.0         1.0      1.0  ...  2.714286       5.0         2.0
# 249       1.0         1.0      2.0  ...  3.285714       1.0         4.0
# 250       NaN         NaN      NaN  ...       NaN       NaN         NaN
#
#         STAIA  STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B     UPSIT  \
# 248  3.434783    3.7         2.722        1.671533        2.255474  4.151515
# 249  3.260870    3.6         3.000        1.496350        1.875912  4.878788
# 250       NaN    NaN           NaN             NaN             NaN  4.515152
#
#      Urine
# 248    2.0
# 249    1.0
# 250    NaN
#
# [3 rows x 47 columns]

# %%
# using melt function [reshape]
df_melted = df_scaled.melt(id_vars='Patient_ID', var_name='Feature', value_name='Value')
print(df_melted.shape)
df_melted.head(2)
# Out:
# (11546, 3)
#    Patient_ID Feature     Value
# 0           1     Age  3.786116
# 1           2     Age  2.232411

# %%
#1. take groupby with respect to Feature and get mean avg of each Feature. 
feat_rating_count = df_melted.groupby('Patient_ID')['Value'].count()

#2. convert into dataframe for better operation work.
feat_rating_count = pd.DataFrame(feat_rating_count)

#3. change column name.
feat_rating_count.columns = ['Value_count']

#4. create new column Patient_ID
feat_rating_count['Patient_ID'] = feat_rating_count.index
feat_rating_count = feat_rating_count.reset_index(drop=True)

# %%
#merging to Rating dataframe so we have collectively all information together..
dframe = df_melted.merge(feat_rating_count, on = 'Patient_ID', how = 'inner')
print(dframe.shape)
dframe.head(2)
# Out:
# (11546, 4)
#    Patient_ID  Feature     Value  Value_count
# 0           1      Age  3.786116           46
# 1           1  Anxiety  2.333333           46

# %%
#create a pivot matrix for user and Feature based on rating value..
RatingMat = dframe.pivot_table(index=['Patient_ID'],columns=['Feature'],values=['Value'],fill_value=0)

#keep a copy of original matrix for future refrence..
Original_RatingMat = RatingMat.copy()
RatingMat.head()
# Out:
#                Value                                                          \
# Feature          Age   Anxiety Apathy    Benton COGSTATE     Clock Cognition
# Patient_ID
# 1           3.786116  2.333333      1  3.503546        1  5.000000         3
# 2           2.232411  2.333333      3  1.943262        1  4.333333         3
# 3           4.267435  1.000000      1  3.975177        5  5.000000         3
# 4           3.521970  1.000000      1  2.659574        5  4.333333         3
# 5           4.052632  2.333333      1  3.503546        1  5.000000         3
#
#                                          ...                            \
# Feature    Constipate Depress DopaDefic  ...     STAIA STAIS  Semantic
# Patient_ID                               ...
# 1            2.333333       2         1  ...  3.434783   5.0  3.285714
# 2            1.000000       1         1  ...  2.565217   3.0  1.785714
# 3            1.000000       1         1  ...  2.913043   3.3  2.428571
# 4            1.000000       1         1  ...  4.130435   3.8  2.714286
# 5            1.000000       2         1  ...  3.956522   3.7  3.357143
#
#                                                                            \
# Feature    SleepDay SleepNight Symbol_Digit Trail_Making_A Trail_Making_B
# Patient_ID
# 1                 3          1     2.833333       3.832117       3.686131
# 2                 3          4     3.133333       1.408759       1.467153
# 3                 3          3     2.555333       3.248175       4.386861
# 4                 3          3     2.500000       2.576642       3.116788
# 5                 5          1     3.200000       1.817518       2.547445
#
#
# Feature        UPSIT Urine
# Patient_ID
# 1           2.333333     2
# 2           1.363636     1
# 3           3.424242     1
# 4           1.242424     2
# 5           3.181818     1
#
# [5 rows x 46 columns]

# %%
#drop multilevel column for better usabiltity...
RatingMat.columns = RatingMat.columns.droplevel()
RatingMat.head(5)
# Out:
# Feature          Age   Anxiety  Apathy    Benton  COGSTATE     Clock  \
# Patient_ID
# 1           3.786116  2.333333       1  3.503546         1  5.000000
# 2           2.232411  2.333333       3  1.943262         1  4.333333
# 3           4.267435  1.000000       1  3.975177         5  5.000000
# 4           3.521970  1.000000       1  2.659574         5  4.333333
# 5           4.052632  2.333333       1  3.503546         1  5.000000
#
# Feature     Cognition  Constipate  Depress  DopaDefic  ...     STAIA  STAIS  \
# Patient_ID                                             ...
# 1                   3    2.333333        2          1  ...  3.434783    5.0
# 2                   3    1.000000        1          1  ...  2.565217    3.0
# 3                   3    1.000000        1          1  ...  2.913043    3.3
# 4                   3    1.000000        1          1  ...  4.130435    3.8
# 5                   3    1.000000        2          1  ...  3.956522    3.7
#
# Feature     Semantic  SleepDay  SleepNight  Symbol_Digit  Trail_Making_A  \
# Patient_ID
# 1           3.285714         3           1      2.833333        3.832117
# 2           1.785714         3           4      3.133333        1.408759
# 3           2.428571         3           3      2.555333        3.248175
# 4           2.714286         3           3      2.500000        2.576642
# 5           3.357143         5           1      3.200000        1.817518
#
# Feature     Trail_Making_B     UPSIT  Urine
# Patient_ID
# 1                 3.686131  2.333333      2
# 2                 1.467153  1.363636      1
# 3                 4.386861  3.424242      1
# 4                 3.116788  1.242424      2
# 5                 2.547445  3.181818      1
#
# [5 rows x 46 columns]

# %%
# Subtracting the mean rating of each user from their ratings
RatingMat_centered = RatingMat.sub(RatingMat.mean(axis=1), axis=0)

# User-wise similarity with centered cosine
user_similarity = cosine_similarity(RatingMat_centered)
user_sim_df = pd.DataFrame(user_similarity, index=RatingMat.index, columns=RatingMat.index)
user_sim_df.head(5)
# Out:
# Patient_ID       1         2         3         4         5         6    \
# Patient_ID
# 1           1.000000  0.417796  0.664229  0.445533  0.589132  0.598594
# 2           0.417796  1.000000  0.501358  0.320770  0.330339  0.253293
# 3           0.664229  0.501358  1.000000  0.675980  0.452688  0.577660
# 4           0.445533  0.320770  0.675980  1.000000  0.452674  0.578553
# 5           0.589132  0.330339  0.452688  0.452674  1.000000  0.754187
#
# Patient_ID       7         8         9         10   ...       243       244  \
# Patient_ID                                          ...
# 1           0.459689  0.536581  0.517297  0.541257  ...  0.422291  0.563044
# 2           0.582968  0.552085  0.620772  0.195227  ...  0.243279  0.505173
# 3           0.577250  0.718700  0.570511  0.403470  ...  0.413508  0.520857
# 4           0.435871  0.562392  0.386839  0.535229  ...  0.465418  0.396327
# 5           0.359338  0.466075  0.577146  0.803612  ...  0.570758  0.642317
#
# Patient_ID       245       246       247       248       249       250  \
# Patient_ID
# 1           0.413753  0.423496  0.508932  0.323075  0.442934  0.613993
# 2           0.153397  0.282986  0.410464  0.139401  0.451399  0.477559
# 3           0.283847  0.492758  0.704036  0.280768  0.516692  0.616067
# 4           0.355826  0.506899  0.585638  0.187548  0.553520  0.393910
# 5           0.468535  0.628111  0.664740  0.498003  0.683278  0.704572
#
# Patient_ID       251       999
# Patient_ID
# 1           0.385480  0.011250
# 2           0.329921  0.095806
# 3           0.455935  0.152042
# 4           0.540896 -0.021256
# 5           0.615637  0.163800
#
# [5 rows x 251 columns]

# %%
# user wise similarity with Euclidean distance
user_Eucsimilarity = 1 - pairwise_distances(RatingMat, metric="euclidean")
user_Eucsim_df = pd.DataFrame(user_Eucsimilarity, index=RatingMat.index, columns=RatingMat.index)
user_Eucsim_df.head(5)
# Out:
# Patient_ID       1         2         3         4         5         6    \
# Patient_ID
# 1           1.000000 -8.201758 -5.960198 -7.978828 -7.263148 -7.947677
# 2          -8.201758  1.000000 -7.297484 -8.412314 -8.874816 -9.279758
# 3          -5.960198 -7.297484  1.000000 -5.696063 -8.112215 -7.401925
# 4          -7.978828 -8.412314 -5.696063  1.000000 -7.864685 -6.792460
# 5          -7.263148 -8.874816 -8.112215 -7.864685  1.000000 -5.452669
#
# Patient_ID       7         8         9          10   ...       243       244  \
# Patient_ID                                           ...
# 1          -8.008556 -7.714100 -7.720991  -8.254988  ... -9.393595 -8.364552
# 2          -6.401548 -7.252046 -6.245880 -10.050777  ... -9.527836 -8.233253
# 3          -6.695412 -5.653864 -6.918432  -8.866888  ... -8.823307 -8.328452
# 4          -7.513197 -7.115497 -8.122083  -7.391746  ... -7.857142 -9.074476
# 5          -8.593813 -8.349701 -6.982468  -4.771915  ... -7.398138 -7.093208
#
# Patient_ID       245       246       247        248       249       250  \
# Patient_ID
# 1          -9.872257 -9.899794 -8.317430 -10.072968 -8.875700 -7.643802
# 2          -9.980459 -9.573837 -9.032847 -10.310964 -7.981355 -7.859032
# 3          -9.827527 -8.679231 -6.231259  -9.805061 -7.799248 -7.029355
# 4          -8.652314 -7.880626 -7.474203  -9.880822 -7.043755 -8.408909
# 5          -8.387278 -7.233763 -6.901173  -8.082910 -6.134923 -5.965663
#
# Patient_ID       251        999
# Patient_ID
# 1          -9.363149 -19.056806
# 2          -8.940838 -16.697264
# 3          -8.348250 -17.405057
# 4          -7.200435 -16.911336
# 5          -6.874943 -16.551922
#
# [5 rows x 251 columns]

# %%
# 1. select the user we have selected Patient_ID 999 
#Get a list of Feature user already watched so we can remove from our recommendation list..

current_user_rating = dframe[(dframe.Patient_ID == 999) & (dframe.Value != 0)]['Feature']
current_user_rating = pd.DataFrame(current_user_rating, columns=['Feature'])

# %%
print(user_sim_df.shape)
print(user_Eucsim_df.shape)
# Out:
# (251, 251)
# (251, 251)

# %%
# put similarity of current user i.e. 999 in a dataframe because later we need for weighted average..

curr_user_similarity = pd.DataFrame(user_sim_df.loc[999])

#just changing column name as similarity for better readability.
curr_user_similarity.rename(columns={999:'Similarity_Score'},inplace=True)
curr_user_similarity.sort_values(by='Similarity_Score', ascending=False, inplace=True)
curr_user_similarity1 = curr_user_similarity.iloc[1:, :]

# Reset index to move it to the first column
curr_user_similarity1.reset_index(inplace=True)

# Rename the index column
curr_user_similarity1.rename(columns={'index': 'Index_Column'}, inplace=True)

# Define a function to categorize values based on the condition
def categorize(x):
    if x < 165:
        return 'Patient'
    else:
        return 'Healthy'

# Apply the function to the first column of the dataframe
curr_user_similarity1['Patient_Type'] = curr_user_similarity1['Patient_ID'].apply(categorize)

# Show the resulting dataframe
curr_user_similarity1.head()
# Out:
# C:\Users\system 4\AppData\Local\Temp\ipykernel_13220\3273874925.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curr_user_similarity1.rename(columns={'index': 'Index_Column'}, inplace=True)
# C:\Users\system 4\AppData\Local\Temp\ipykernel_13220\3273874925.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   curr_user_similarity1['Patient_Type'] = curr_user_similarity1['Patient_ID'].apply(categorize)
#    Patient_ID  Similarity_Score Patient_Type
# 0         135          0.505485      Patient
# 1          97          0.424619      Patient
# 2         173          0.421041      Healthy
# 3         133          0.415994      Patient
# 4          78          0.403935      Patient

# %% [markdown]
# The Patient_ID most similar to the input user is showing, from 5 we can decide patient or healthy based on
# more number of healthy or patient among those top 5 list generated above.

# %%
similar_user = curr_user_similarity1.iloc[:5, :]
counts = similar_user['Patient_Type'].value_counts()
most_occurring_value = counts.index[0]
print("The user might fall under category of", most_occurring_value)
# Out:
# The user might fall under category of Patient

# %% [markdown]
# #As per the user category healthy or PD, we will give values to other unfilled features by that user

# %% [markdown]
# # Predicting Scoring of user: Top users of its category

# %%
select_simil_user = similar_user.loc[similar_user['Patient_Type'] == most_occurring_value]

# %%
df_simil = df1[df1['Patient_ID'].isin(select_simil_user['Patient_ID'])]
df_simil.head()
# Out:
#      Patient_ID        Age  Anxiety  Apathy  Benton  Clock  Cognition  \
# 77           78  56.975065        0       1    9.55      5          0
# 96           97  62.265514        1       2   15.69      7          0
# 131         133  49.165469        1       1    9.32      7          1
# 133         135  66.384280        0       2   12.16      7          0
#
#      COGSTATE  Constipate  Depress  ...  Semantic  SleepDay  SleepNight  \
# 77          1           1        1  ...        46         0           2
# 96          1           0        2  ...        38         2           0
# 131         1           0        1  ...        50         1           2
# 133         1           0        1  ...        49         2           1
#
#      STAIA  STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 77      43     45     43.750000              45             262     29      0
# 96      35     35     22.500000              37             158     22      1
# 131     43     45     51.000000              29              59     37      0
# 133     49     48     41.669998              35             170     38      1
#
# [4 rows x 47 columns]

# %%
similar_user.head()
# Out:
#    Patient_ID  Similarity_Score Patient_Type
# 0         135          0.505485      Patient
# 1          97          0.424619      Patient
# 2         173          0.421041      Healthy
# 3         133          0.415994      Patient
# 4          78          0.403935      Patient

# %%
similar_user = similar_user.drop(['Patient_Type'], axis=1)
similar_user.head(2)
# Out:
#    Patient_ID  Similarity_Score
# 0         135          0.505485
# 1          97          0.424619

# %%
df_score = pd.merge(similar_user, df_simil, on = 'Patient_ID', how = 'inner')
df_score.head()
# Out:
#    Patient_ID  Similarity_Score        Age  Anxiety  Apathy  Benton  Clock  \
# 0         135          0.505485  66.384280        0       2   12.16      7
# 1          97          0.424619  62.265514        1       2   15.69      7
# 2         133          0.415994  49.165469        1       1    9.32      7
# 3          78          0.403935  56.975065        0       1    9.55      5
#
#    Cognition  COGSTATE  Constipate  ...  Semantic  SleepDay  SleepNight  \
# 0          0         1           0  ...        49         2           1
# 1          0         1           0  ...        38         2           0
# 2          1         1           0  ...        50         1           2
# 3          0         1           1  ...        46         0           2
#
#    STAIA  STAIS  Symbol_Digit  Trail_Making_A  Trail_Making_B  UPSIT  Urine
# 0     49     48     41.669998              35             170     38      1
# 1     35     35     22.500000              37             158     22      1
# 2     43     45     51.000000              29              59     37      0
# 3     43     45     43.750000              45             262     29      0
#
# [4 rows x 48 columns]

# %%
# Example DataFrame Y with some filled and some NaN values
X = df_simil
Y = df3.drop(['Patient_ID', 'Age'], axis = 1)

# Extract the weights from the second column of df_score i.e. extracting Similarity_Score
weights = df_score.iloc[:, 1]

# Extract the values to be averaged from the remaining columns of X
values = X.iloc[:, 2:]

# Compute the weighted average of each column
weighted_avg_cols = np.average(values, axis=0, weights=weights)

# Create a dictionary that maps column names to weighted average values
fill_values = {col: val for col, val in zip(Y.columns, weighted_avg_cols)}

# Fill NaN values in DataFrame Y with the mean values
Y = Y.fillna(fill_values)
col_Age = df3.pop('Age')
Y.insert(0, 'Age', col_Age)
Y

# %% [markdown]
# colX = df_simil
# colY = df3.drop(['Patient_ID', 'Age'], axis = 1)
# col_weights = df_score.iloc[:, 1]
# values = colX.iloc[:, 2:]
# weighted_avg_cols = np.average(values, axis=0, weights=col_weights)
# fill_values = {col: val for col, val in zip(colY.columns, weighted_avg_cols)}
# colY = colY.fillna(fill_values)
# col_Age = df3.pop('Age')
# colY.insert(0, 'Age', col_Age)
# colY
