# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %cd Z:\PPMI_Data\Excels\Raw_And_More
# Out:
# Z:\PPMI_Data\Excels\Raw_And_More

# %%
Cpg_File = pd.read_csv ("beta_post_Funnorm_PPMI_EPICn524final030618.csv")
Cpg_File.head(3)
# Out:
#             200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# cg14817997             0.834027             0.849201             0.772995
# cg26928153             0.945589             0.948538             0.962199
# cg16269199             0.845186             0.911488             0.948206
#
#             200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# cg14817997             0.885288             0.772547             0.756429
# cg26928153             0.944048             0.926306             0.956061
# cg16269199             0.913622             0.778551             0.903924
#
#             200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  \
# cg14817997             0.719766             0.775910             0.768914
# cg26928153             0.912988             0.955983             0.957120
# cg16269199             0.742258             0.934683             0.897787
#
#             200973410167_R05C01  ...  200989060089_R02C01  \
# ...

# %%
Cpg_File.index.name ='CpG'
Cpg_File.reset_index(inplace=True)
Cpg_File.head(3)
# Out:
#           CpG  200973410159_R03C01  200991620021_R01C01  200991620021_R03C01  \
# 0  cg14817997             0.834027             0.849201             0.772995
# 1  cg26928153             0.945589             0.948538             0.962199
# 2  cg16269199             0.845186             0.911488             0.948206
#
#    200989060105_R03C01  200989060135_R07C01  200989060162_R04C01  \
# 0             0.885288             0.772547             0.756429
# 1             0.944048             0.926306             0.956061
# 2             0.913622             0.778551             0.903924
#
#    200973410167_R04C01  200973410143_R01C01  200973410143_R06C01  ...  \
# 0             0.719766             0.775910             0.768914  ...
# 1             0.912988             0.955983             0.957120  ...
# 2             0.742258             0.934683             0.897787  ...
#
#    200989060089_R02C01  200989060089_R01C01  200989060089_R04C01  \
# ...

# %%
dft = Cpg_File.transpose()
dft.head(2)
# Out:
#                          0           1           2           3       \
# CpG                  cg14817997  cg26928153  cg16269199  cg13869341
# 200973410159_R03C01    0.834027    0.945589    0.845186    0.928455
#
#                          4           5           6           7       \
# CpG                  cg14008030  cg12045430  cg20826792  cg20253340
# 200973410159_R03C01    0.582476     0.11692    0.059963    0.523214
#
#                          8           9       ...      864057      864058  \
# CpG                  cg02404219  cg21870274  ...  cg02995750  cg14467015
# 200973410159_R03C01    0.758915    0.887897  ...    0.693517    0.128043
#
#                          864059      864060      864061      864062  \
# CpG                  cg15516537  cg05999368  cg15462332  cg00335297
# 200973410159_R03C01    0.478095    0.300037    0.270093    0.217182
#
#                          864063      864064      864065      864066
# ...

# %%
dft.rename(columns=dft.iloc[0], inplace = True)
dft.head(2)
# Out:
#                      cg14817997  cg26928153  cg16269199  cg13869341  \
# CpG                  cg14817997  cg26928153  cg16269199  cg13869341
# 200973410159_R03C01    0.834027    0.945589    0.845186    0.928455
#
#                      cg14008030  cg12045430  cg20826792  cg20253340  \
# CpG                  cg14008030  cg12045430  cg20826792  cg20253340
# 200973410159_R03C01    0.582476     0.11692    0.059963    0.523214
#
#                      cg02404219  cg21870274  ...  cg02995750  cg14467015  \
# CpG                  cg02404219  cg21870274  ...  cg02995750  cg14467015
# 200973410159_R03C01    0.758915    0.887897  ...    0.693517    0.128043
#
#                      cg15516537  cg05999368  cg15462332  cg00335297  \
# CpG                  cg15516537  cg05999368  cg15462332  cg00335297
# 200973410159_R03C01    0.478095    0.300037    0.270093    0.217182
#
#                      cg02600718  cg10488260  cg07587934  cg16855331
# ...

# %%
dft.index.name ='CpG'
dft.reset_index(inplace=True)
dft.head(2)
# Out:
#                    CpG  cg14817997  cg26928153  cg16269199  cg13869341  \
# 0                  CpG  cg14817997  cg26928153  cg16269199  cg13869341
# 1  200973410159_R03C01    0.834027    0.945589    0.845186    0.928455
#
#    cg14008030  cg12045430  cg20826792  cg20253340  cg02404219  ...  \
# 0  cg14008030  cg12045430  cg20826792  cg20253340  cg02404219  ...
# 1    0.582476     0.11692    0.059963    0.523214    0.758915  ...
#
#    cg02995750  cg14467015  cg15516537  cg05999368  cg15462332  cg00335297  \
# 0  cg02995750  cg14467015  cg15516537  cg05999368  cg15462332  cg00335297
# 1    0.693517    0.128043    0.478095    0.300037    0.270093    0.217182
#
#    cg02600718  cg10488260  cg07587934  cg16855331
# 0  cg02600718  cg10488260  cg07587934  cg16855331
# 1    0.244948    0.273165    0.781204    0.539283
#
# [2 rows x 864068 columns]

# %%
dft = dft.drop ([0], axis = 0)
dft.head(2)
# Out:
#                    CpG cg14817997 cg26928153 cg16269199 cg13869341 cg14008030  \
# 1  200973410159_R03C01   0.834027   0.945589   0.845186   0.928455   0.582476
# 2  200991620021_R01C01   0.849201   0.948538   0.911488   0.885379    0.53699
#
#   cg12045430 cg20826792 cg20253340 cg02404219  ... cg02995750 cg14467015  \
# 1    0.11692   0.059963   0.523214   0.758915  ...   0.693517   0.128043
# 2   0.097013   0.083405   0.539284   0.670439  ...   0.887561   0.850783
#
#   cg15516537 cg05999368 cg15462332 cg00335297 cg02600718 cg10488260  \
# 1   0.478095   0.300037   0.270093   0.217182   0.244948   0.273165
# 2   0.860009   0.736628   0.870584   0.742256   0.247742   0.845816
#
#   cg07587934 cg16855331
# 1   0.781204   0.539283
# 2   0.716938   0.519672
#
# [2 rows x 864068 columns]

# %%
dft.rename (columns = {"CpG" : "Sentrix"}, inplace = True)
dft.head(2)
# Out:
#                Sentrix cg14817997 cg26928153 cg16269199 cg13869341 cg14008030  \
# 1  200973410159_R03C01   0.834027   0.945589   0.845186   0.928455   0.582476
# 2  200991620021_R01C01   0.849201   0.948538   0.911488   0.885379    0.53699
#
#   cg12045430 cg20826792 cg20253340 cg02404219  ... cg02995750 cg14467015  \
# 1    0.11692   0.059963   0.523214   0.758915  ...   0.693517   0.128043
# 2   0.097013   0.083405   0.539284   0.670439  ...   0.887561   0.850783
#
#   cg15516537 cg05999368 cg15462332 cg00335297 cg02600718 cg10488260  \
# 1   0.478095   0.300037   0.270093   0.217182   0.244948   0.273165
# 2   0.860009   0.736628   0.870584   0.742256   0.247742   0.845816
#
#   cg07587934 cg16855331
# 1   0.781204   0.539283
# 2   0.716938   0.519672
#
# [2 rows x 864068 columns]

# %%
df1 = pd.read_csv ("Sentrix_APPRDX_of524Methyl_Female.csv")
df1.head(2)
# Out:
#                Sentrix  APPRDX
# 0  200973410159_R03C01       2
# 1  200991620021_R03C01       1

# %%
df = pd.merge (df1, dft, on = 'Sentrix', how = 'inner')
df.head(2)
# Out:
#                Sentrix  APPRDX cg14817997 cg26928153 cg16269199 cg13869341  \
# 0  200973410159_R03C01       2   0.834027   0.945589   0.845186   0.928455
# 1  200991620021_R03C01       1   0.772995   0.962199   0.948206   0.881643
#
#   cg14008030 cg12045430 cg20826792 cg20253340  ... cg02995750 cg14467015  \
# 0   0.582476    0.11692   0.059963   0.523214  ...   0.693517   0.128043
# 1   0.599218   0.132622   0.102972   0.578563  ...   0.259092   0.296889
#
#   cg15516537 cg05999368 cg15462332 cg00335297 cg02600718 cg10488260  \
# 0   0.478095   0.300037   0.270093   0.217182   0.244948   0.273165
# 1   0.301841   0.256767   0.246476   0.249338    0.25963   0.291222
#
#   cg07587934 cg16855331
# 0   0.781204   0.539283
# 1   0.779612   0.481618
#
# [2 rows x 864069 columns]

# %%
df = df.drop('Sentrix', axis=1)

# %% [markdown]
# ## Patient

# %%
df_P = df[df['APPRDX'] == 1]
print(df.shape)

# Extract the dependent binary variable and independent columns
dependent_col = df_P.iloc[:, 0]
independent_cols = df_P.iloc[:, 1:]

# Calculate the average and standard deviation for each independent column
average_values = independent_cols.mean()
std_deviation_values = independent_cols.std()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(average_values, std_deviation_values, marker='o', s = 5, color='red')
plt.title('Average vs. Standard Deviation', fontsize=18, fontweight='bold')
plt.xlabel('Average Value', fontsize=14)
plt.ylabel('Standard Deviation', fontsize=14)

# Set axis label fontweight directly
ax = plt.gca()  # Get current axis
ax.xaxis.label.set_fontweight('bold')
ax.yaxis.label.set_fontweight('bold')

# Set tick label fontweight
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
plt.grid(True)
plt.savefig('CpG_All_average_std_deviation_Female_Diseased.pdf', format='pdf', bbox_inches='tight', orientation='landscape')
plt.savefig('CpG_All_average_std_deviation_Female_Diseased.svg', format='svg', bbox_inches='tight', orientation='landscape')
plt.show()
# Out:
# (150, 864068)

# %% [markdown]
# ## Healthy

# %%
df_H = df[df['APPRDX'] == 2]
print(df_H.shape)

# Extract the dependent binary variable and independent columns
dependent_col = df_H.iloc[:, 0]
independent_cols = df_H.iloc[:, 1:]

# Calculate the average and standard deviation for each independent column
average_values = independent_cols.mean()
std_deviation_values = independent_cols.std()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(average_values, std_deviation_values, marker='s', s = 5, color='green')
plt.title('Average vs. Standard Deviation', fontsize=18, fontweight='bold')
plt.xlabel('Average Value', fontsize=14)
plt.ylabel('Standard Deviation', fontsize=14)

# Set axis label fontweight directly
ax = plt.gca()  # Get current axis
ax.xaxis.label.set_fontweight('bold')
ax.yaxis.label.set_fontweight('bold')

# Set tick label fontweight
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
plt.grid(True)
plt.savefig('CpG_All_average_std_deviation_Female_Healthy.pdf', format='pdf', bbox_inches='tight', orientation='landscape')
plt.savefig('CpG_All_average_std_deviation_Female_Healthy.svg', format='svg', bbox_inches='tight', orientation='landscape')
plt.show()
# Out:
# (39, 864068)

# %% [markdown]
# ## Both merged

# %%
# Extract the dependent binary variable and independent columns
dependent_col = df.iloc[:, 0]
independent_cols = df.iloc[:, 1:]

# Calculate the average and standard deviation for each independent column
average_values = independent_cols.mean()
std_deviation_values = independent_cols.std()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(average_values, std_deviation_values, marker='s', s = 2, color='deepskyblue')
plt.title('Average vs. Standard Deviation', fontsize=18, fontweight='bold')
plt.xlabel('Average Value', fontsize=14)
plt.ylabel('Standard Deviation', fontsize=14)

# Set axis label fontweight directly
ax = plt.gca()  # Get current axis
ax.xaxis.label.set_fontweight('bold')
ax.yaxis.label.set_fontweight('bold')

# Set tick label fontweight
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
plt.grid(True)
plt.savefig('CpG_All_average_std_deviation_Female_Merged.pdf', format='pdf', bbox_inches='tight', orientation='landscape')
plt.savefig('CpG_All_average_std_deviation_Female_Merged.svg', format='svg', bbox_inches='tight', orientation='landscape')
plt.show()

# %% [markdown]
# ## Both Patient & Healthy

# %%
# Separate data based on APPRDX values
data_apprdx_1 = df[df['APPRDX'] == 1]
data_apprdx_2 = df[df['APPRDX'] == 2]

# Calculate average and standard deviation for both cases
avg_std_1 = data_apprdx_1.iloc[:, 1:].agg(['mean', 'std']).transpose()
avg_std_2 = data_apprdx_2.iloc[:, 1:].agg(['mean', 'std']).transpose()

# Plotting
plt.figure(figsize=(10, 6))
plt.scatter(avg_std_1['mean'], avg_std_1['std'], marker='o', s = 2, color='red', label='Patient')
plt.scatter(avg_std_2['mean'], avg_std_2['std'], marker='s', s = 2, color='green', label='Healthy')
plt.title('Average vs. Standard Deviation', fontsize=18, fontweight='bold')
plt.xlabel('Average Value', fontsize=14)
plt.ylabel('Standard Deviation', fontsize=14)
# Make the legend labels bold
legend = plt.legend()
for label in legend.get_texts():
    label.set_fontweight('bold')

# Set axis label fontweight directly
ax = plt.gca()  # Get current axis
ax.xaxis.label.set_fontweight('bold')
ax.yaxis.label.set_fontweight('bold')

# Set tick label fontweight
for tick in ax.xaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
for tick in ax.yaxis.get_major_ticks():
    tick.label1.set_fontweight('bold')
plt.grid(True)
plt.savefig('CpG_All_average_std_deviation_Female.pdf', format='pdf', bbox_inches='tight', orientation='landscape')
plt.savefig('CpG_All_average_std_deviation_Female.svg', format='svg', bbox_inches='tight', orientation='landscape')
plt.show()
